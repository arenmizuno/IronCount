# %% [markdown]
# # MediaPipe + CNN + LSTM Classification Model
# ## ADSP 32023 - Advanced Computer Vision Using Deep Learning
# ## Spring 2026

# %%
# ============================================================
# 0. Install packages
# ============================================================
# !pip install -q torch torchvision torchaudio coremltools scikit-learn matplotlib pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.2 MB/s eta 0:00:00

# %%
# ============================================================
# 1. Imports
# ============================================================
import os
import json
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight
from google.colab import drive

import coremltools as ct

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Device:", DEVICE)
# Out:
# WARNING:coremltools:scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# WARNING:coremltools:XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING:coremltools:TensorFlow version 2.20.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# WARNING:coremltools:Torch version 2.11.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# Device: cuda

# %%
# ============================================================
# 2. Paths + config
# ============================================================
drive.mount("/content/drive")
PROJECT_DIR = "/content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/"

SAVE_DIR = os.path.join(PROJECT_DIR, "data", "preprocessed")
MODEL_DIR = os.path.join(PROJECT_DIR, "models")
GRAPH_DIR = os.path.join(PROJECT_DIR, "graphs")
RESULT_DIR = os.path.join(PROJECT_DIR, "data")
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(RESULT_DIR, exist_ok=True)

EXPERIMENT_NAME = "torch_cnn_lstm_coreml"
OUTPUT_MODEL_DIR = os.path.join(MODEL_DIR, EXPERIMENT_NAME)
OUTPUT_GRAPH_DIR = os.path.join(GRAPH_DIR, EXPERIMENT_NAME)
OUTPUT_RESULT_DIR = os.path.join(RESULT_DIR, EXPERIMENT_NAME)
os.makedirs(OUTPUT_MODEL_DIR, exist_ok=True)
os.makedirs(OUTPUT_GRAPH_DIR, exist_ok=True)
os.makedirs(OUTPUT_RESULT_DIR, exist_ok=True)

BATCH_SIZE = 32
EPOCHS = 80
N_SPLITS = 5

CNN_CHANNELS_1 = 96
CNN_CHANNELS_2 = 128
CNN_CHANNELS_3 = 192

HIDDEN_SIZE = 128
NUM_LAYERS = 1
DROPOUT = 0.30

LR = 1e-3
WEIGHT_DECAY = 1e-5
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# 3. Load new extracted MediaPipe data
# ============================================================
X_verified = np.load(os.path.join(SAVE_DIR, "X_verified_mediapipe.npy"))
y_verified = np.load(os.path.join(SAVE_DIR, "y_verified.npy"))

X_test = np.load(os.path.join(SAVE_DIR, "X_test_mediapipe.npy"))
y_test = np.load(os.path.join(SAVE_DIR, "y_test.npy"))

kept_verified_df = pd.read_csv(
    os.path.join(SAVE_DIR, "kept_verified_mediapipe_dataset.csv")
)

kept_test_df = pd.read_csv(
    os.path.join(SAVE_DIR, "kept_test_mediapipe_dataset.csv")
)

with open(os.path.join(SAVE_DIR, "label_names.json"), "r") as f:
    label_names = json.load(f)

num_classes = len(label_names)

SEQUENCE_LENGTH = X_verified.shape[1]
FEATURE_SIZE = X_verified.shape[2]

print("X_verified:", X_verified.shape)
print("y_verified:", y_verified.shape)

print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("SEQUENCE_LENGTH:", SEQUENCE_LENGTH)
print("FEATURE_SIZE:", FEATURE_SIZE)
print("num_classes:", num_classes)
print(label_names)
# Out:
# X_verified: (11897, 48, 300)
# y_verified: (11897,)
# X_test: (1293, 48, 300)
# y_test: (1293,)
# SEQUENCE_LENGTH: 48
# FEATURE_SIZE: 300
# num_classes: 21
# ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raise', 'leg extension', 'leg raises', 'pull Up', 'push-up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep Pushdown', 'tricep dips']

# %%
# ============================================================
# 4. Scaling + augmentation helpers
# ============================================================
def scale_sequence_data(X_train, X_val):
    n_train, t, f = X_train.shape
    n_val = X_val.shape[0]

    scaler = StandardScaler()

    X_train_flat = X_train.reshape(-1, f)
    X_val_flat = X_val.reshape(-1, f)

    X_train_scaled = scaler.fit_transform(
        X_train_flat
    ).reshape(n_train, t, f)

    X_val_scaled = scaler.transform(
        X_val_flat
    ).reshape(n_val, t, f)

    return (
        X_train_scaled.astype(np.float32),
        X_val_scaled.astype(np.float32),
        scaler
    )


def scale_with_existing_scaler(X, scaler):
    n, t, f = X.shape

    X_flat = X.reshape(-1, f)

    X_scaled = scaler.transform(
        X_flat
    ).reshape(n, t, f)

    return X_scaled.astype(np.float32)


def augment_sequence(
    seq,
    noise_std=0.015,
    scale_std=0.025,
    dropout_prob=0.06,
    time_shift_max=4,
    time_mask_prob=0.15,
    time_mask_max=5,
    feature_mask_prob=0.04
):
    aug = seq.copy()

    # Small Gaussian feature noise
    aug += np.random.normal(
        0,
        noise_std,
        size=aug.shape
    )

    # Global scale jitter
    aug *= np.random.normal(
        1.0,
        scale_std
    )

    # Random time shift
    shift = np.random.randint(
        -time_shift_max,
        time_shift_max + 1
    )

    aug = np.roll(
        aug,
        shift=shift,
        axis=0
    )

    # Random frame dropout: repeat previous frame
    for i in range(1, len(aug)):
        if np.random.rand() < dropout_prob:
            aug[i] = aug[i - 1]

    # Time masking
    if np.random.rand() < time_mask_prob:
        mask_len = np.random.randint(
            1,
            time_mask_max + 1
        )

        start = np.random.randint(
            0,
            max(1, len(aug) - mask_len)
        )

        replacement = aug[start - 1] if start > 0 else aug[start]

        aug[start:start + mask_len] = replacement

    # Feature masking
    feature_mask = (
        np.random.rand(aug.shape[1]) < feature_mask_prob
    )

    aug[:, feature_mask] = 0

    return aug.astype(np.float32)


def make_augmented_training_data(
    X_train,
    y_train,
    copies=2
):
    X_list = [X_train]
    y_list = [y_train]

    for _ in range(copies):
        X_aug = np.array(
            [augment_sequence(seq) for seq in X_train],
            dtype=np.float32
        )

        X_list.append(X_aug)
        y_list.append(y_train)

    return (
        np.concatenate(X_list, axis=0),
        np.concatenate(y_list, axis=0)
    )

# %%
# ============================================================
# 5. PyTorch CNN + LSTM + Attention model
# ============================================================
class WorkoutClassifierCNNLSTM(nn.Module):
    """
    Hybrid classifier for workout recognition.

    Architecture:
    1. Conv1D layers extract local motion patterns across time.
    2. LSTM layer models longer temporal sequence patterns.
    3. Attention mechanism learns which frames matter most.
    4. Fully connected classifier outputs exercise logits.

    Input shape:
        (batch, sequence_length, feature_size)

    Internally Conv1D expects:
        (batch, feature_size, sequence_length)
    """

    def __init__(
        self,
        input_size,
        cnn_channels_1,
        cnn_channels_2,
        cnn_channels_3,
        hidden_size,
        num_layers,
        num_classes,
        dropout=0.3
    ):
        super().__init__()

        self.conv_block = nn.Sequential(
            nn.Conv1d(
                in_channels=input_size,
                out_channels=cnn_channels_1,
                kernel_size=3,
                padding=1
            ),
            nn.BatchNorm1d(cnn_channels_1),
            nn.ReLU(),
            nn.Dropout(dropout * 0.6),

            nn.Conv1d(
                in_channels=cnn_channels_1,
                out_channels=cnn_channels_2,
                kernel_size=5,
                padding=2
            ),
            nn.BatchNorm1d(cnn_channels_2),
            nn.ReLU(),
            nn.Dropout(dropout * 0.7),

            nn.Conv1d(
                in_channels=cnn_channels_2,
                out_channels=cnn_channels_3,
                kernel_size=3,
                padding=1
            ),
            nn.BatchNorm1d(cnn_channels_3),
            nn.ReLU()
        )

        self.lstm = nn.LSTM(
            input_size=cnn_channels_3,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=True
        )

        self.layer_norm = nn.LayerNorm(hidden_size * 2)

        self.attention = nn.Linear(hidden_size * 2, 1)

        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, 256),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # Input: (batch, time, features)
        # Conv1D wants: (batch, features, time)
        x = x.transpose(1, 2)

        x = self.conv_block(x)

        # Back to: (batch, time, channels)
        x = x.transpose(1, 2)

        lstm_out, _ = self.lstm(x)

        lstm_out = self.layer_norm(lstm_out)

        attn_scores = self.attention(lstm_out)
        attn_weights = torch.softmax(attn_scores, dim=1)

        context = torch.sum(lstm_out * attn_weights, dim=1)

        logits = self.classifier(context)

        return logits


def count_parameters(model):
    total_params = sum(
        p.numel()
        for p in model.parameters()
    )

    trainable_params = sum(
        p.numel()
        for p in model.parameters()
        if p.requires_grad
    )

    print(model)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {trainable_params:,}")

# %%
# ============================================================
# 6. Training helpers
# ============================================================
def train_one_epoch(
    model,
    loader,
    criterion,
    optimizer,
    device
):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for batch_X, batch_y in loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)

        loss.backward()

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            max_norm=1.0
        )

        optimizer.step()

        total_loss += loss.item()

        _, predicted = outputs.max(1)

        correct += predicted.eq(batch_y).sum().item()
        total += batch_y.size(0)

    return total_loss / len(loader), correct / total


def evaluate(
    model,
    loader,
    criterion,
    device
):
    model.eval()

    total_loss = 0
    correct = 0
    total = 0

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch_X, batch_y in loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)

            total_loss += loss.item()

            _, predicted = outputs.max(1)

            correct += predicted.eq(batch_y).sum().item()
            total += batch_y.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(batch_y.cpu().numpy())

    return (
        total_loss / len(loader),
        correct / total,
        all_preds,
        all_labels
    )

# %%
# ============================================================
# 7. CNN + LSTM Hyperparameter Search Space
# ============================================================

HYPERPARAM_GRID = [
    {
        "cnn_channels_1": 96,
        "cnn_channels_2": 128,
        "cnn_channels_3": 192,
        "hidden_size": 128,
        "num_layers": 1,
        "dropout": 0.30,
        "lr": 1e-3,
        "weight_decay": 1e-5
    },
    {
        "cnn_channels_1": 96,
        "cnn_channels_2": 160,
        "cnn_channels_3": 224,
        "hidden_size": 128,
        "num_layers": 1,
        "dropout": 0.35,
        "lr": 1e-3,
        "weight_decay": 1e-5
    },
    {
        "cnn_channels_1": 128,
        "cnn_channels_2": 160,
        "cnn_channels_3": 224,
        "hidden_size": 256,
        "num_layers": 1,
        "dropout": 0.35,
        "lr": 5e-4,
        "weight_decay": 1e-5
    },
    {
        "cnn_channels_1": 96,
        "cnn_channels_2": 128,
        "cnn_channels_3": 192,
        "hidden_size": 128,
        "num_layers": 2,
        "dropout": 0.40,
        "lr": 5e-4,
        "weight_decay": 1e-5
    }
]

# %%
# ============================================================
# 8. Hyperparameter Search with GroupKFold
# ============================================================

best_all_true = None
best_all_pred = None
best_fold_accuracies = None
best_fold_macro_f1 = None
best_fold_weighted_f1 = None
best_history = None
best_fold = None

gkf = GroupKFold(n_splits=N_SPLITS)
groups = kept_verified_df["filepath"].values

search_results = []

best_config = None
best_cv_macro_f1 = -1
best_cv_accuracy = -1

for config_id, config in enumerate(HYPERPARAM_GRID, start=1):
    print("\n" + "=" * 70)
    print(f"Testing config {config_id}/{len(HYPERPARAM_GRID)}")
    print(config)
    print("=" * 70)

    fold_accuracies = []
    fold_macro_f1 = []
    fold_weighted_f1 = []

    config_all_true = []
    config_all_pred = []
    config_best_history = None
    config_best_fold = None
    config_best_acc = 0

    for fold, (train_idx, val_idx) in enumerate(
        gkf.split(X_verified, y_verified, groups=groups),
        start=1
    ):
        print(f"\n---------- Config {config_id} | Fold {fold} ----------")

        X_train_raw = X_verified[train_idx]
        X_val_raw = X_verified[val_idx]

        y_train = y_verified[train_idx]
        y_val = y_verified[val_idx]

        X_train, X_val, scaler = scale_sequence_data(X_train_raw, X_val_raw)

        X_train_aug, y_train_aug = make_augmented_training_data(
            X_train,
            y_train,
            copies=2
        )

        train_loader = DataLoader(
            TensorDataset(torch.FloatTensor(X_train_aug), torch.LongTensor(y_train_aug)),
            batch_size=BATCH_SIZE,
            shuffle=True,
            num_workers=2,
            pin_memory=True
        )

        val_loader = DataLoader(
            TensorDataset(torch.FloatTensor(X_val), torch.LongTensor(y_val)),
            batch_size=BATCH_SIZE,
            shuffle=False
        )

        model = WorkoutClassifierCNNLSTM(
            input_size=FEATURE_SIZE,
            cnn_channels_1=config["cnn_channels_1"],
            cnn_channels_2=config["cnn_channels_2"],
            cnn_channels_3=config["cnn_channels_3"],
            hidden_size=config["hidden_size"],
            num_layers=config["num_layers"],
            num_classes=num_classes,
            dropout=config["dropout"]
        ).to(DEVICE)

        if config_id == 1 and fold == 1:
            count_parameters(model)

        class_weights_arr = compute_class_weight(
            class_weight="balanced",
            classes=np.unique(y_train_aug),
            y=y_train_aug
        )

        criterion = nn.CrossEntropyLoss(
            weight=torch.FloatTensor(class_weights_arr).to(DEVICE)
        )

        optimizer = optim.Adam(
            model.parameters(),
            lr=config["lr"],
            weight_decay=config["weight_decay"]
        )

        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode="min",
            patience=5,
            factor=0.5
        )

        fold_best_acc = 0
        fold_best_state = None
        patience = 15
        patience_counter = 0

        history = {
            "train_loss": [],
            "val_loss": [],
            "train_acc": [],
            "val_acc": []
        }

        for epoch in range(1, EPOCHS + 1):
            train_loss, train_acc = train_one_epoch(
                model,
                train_loader,
                criterion,
                optimizer,
                DEVICE
            )

            val_loss, val_acc, val_preds, val_labels = evaluate(
                model,
                val_loader,
                criterion,
                DEVICE
            )

            scheduler.step(val_loss)

            history["train_loss"].append(train_loss)
            history["val_loss"].append(val_loss)
            history["train_acc"].append(train_acc)
            history["val_acc"].append(val_acc)

            if val_acc > fold_best_acc:
                fold_best_acc = val_acc
                fold_best_state = {
                    k: v.cpu().clone()
                    for k, v in model.state_dict().items()
                }
                patience_counter = 0
            else:
                patience_counter += 1

            if epoch == 1 or epoch % 5 == 0:
                print(
                    f"Epoch {epoch:03d}/{EPOCHS} | "
                    f"Train Acc: {train_acc:.4f} | "
                    f"Val Acc: {val_acc:.4f} | "
                    f"Val Loss: {val_loss:.4f}"
                )

            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch}")
                break

        model.load_state_dict(fold_best_state)
        model = model.to(DEVICE)

        val_loss, val_acc, val_preds, val_labels = evaluate(
            model,
            val_loader,
            criterion,
            DEVICE
        )

        macro = f1_score(val_labels, val_preds, average="macro")
        weighted = f1_score(val_labels, val_preds, average="weighted")

        fold_accuracies.append(val_acc)
        fold_macro_f1.append(macro)
        fold_weighted_f1.append(weighted)

        config_all_true.extend(val_labels)
        config_all_pred.extend(val_preds)

        if val_acc > config_best_acc:
            config_best_acc = val_acc
            config_best_history = history
            config_best_fold = fold

        print(f"Fold {fold} Accuracy: {val_acc:.4f}")
        print(f"Fold {fold} Macro F1: {macro:.4f}")
        print(f"Fold {fold} Weighted F1: {weighted:.4f}")

    mean_acc = np.mean(fold_accuracies)
    mean_macro = np.mean(fold_macro_f1)
    mean_weighted = np.mean(fold_weighted_f1)

    result = {
        "config_id": config_id,
        **config,
        "mean_accuracy": mean_acc,
        "mean_macro_f1": mean_macro,
        "mean_weighted_f1": mean_weighted
    }

    search_results.append(result)

    if mean_macro > best_cv_macro_f1:
        best_cv_macro_f1 = mean_macro
        best_cv_accuracy = mean_acc
        best_config = config

        best_all_true = config_all_true
        best_all_pred = config_all_pred
        best_fold_accuracies = fold_accuracies
        best_fold_macro_f1 = fold_macro_f1
        best_fold_weighted_f1 = fold_weighted_f1
        best_history = config_best_history
        best_fold = config_best_fold

print("\n================ BEST HYPERPARAMETERS ================")
print("Best config:", best_config)
print("Best mean CV macro F1:", best_cv_macro_f1)
print("Best mean CV accuracy:", best_cv_accuracy)

search_results_df = pd.DataFrame(search_results)
display(search_results_df)

SEARCH_RESULTS_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_lstm_hyperparameter_search_results.csv"
)

search_results_df.to_csv(SEARCH_RESULTS_PATH, index=False)
# Out:
# ======================================================================
# Testing config 1/4
# {'cnn_channels_1': 96, 'cnn_channels_2': 128, 'cnn_channels_3': 192, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 1 | Fold 1 ----------
# WorkoutClassifierCNNLSTM(
#   (conv_block): Sequential(
#     (0): Conv1d(300, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.18, inplace=False)
#     (4): Conv1d(96, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.21, inplace=False)
#     (8): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#   )
#   (lstm): LSTM(192, 128, batch_first=True, bidirectional=True)
#   (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (attention): Linear(in_features=256, out_features=1, bias=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )
# Total params: 654,710
# Trainable params: 654,710
# Epoch 001/80 | Train Acc: 0.6435 | Val Acc: 0.7273 | Val Loss: 0.8662
# Epoch 005/80 | Train Acc: 0.8974 | Val Acc: 0.8433 | Val Loss: 0.7699
# Epoch 010/80 | Train Acc: 0.9613 | Val Acc: 0.8424 | Val Loss: 0.9795
# Epoch 015/80 | Train Acc: 0.9778 | Val Acc: 0.8424 | Val Loss: 1.1906
# Epoch 020/80 | Train Acc: 0.9902 | Val Acc: 0.8605 | Val Loss: 1.3469
# Epoch 025/80 | Train Acc: 0.9949 | Val Acc: 0.8630 | Val Loss: 1.4282
# Epoch 030/80 | Train Acc: 0.9954 | Val Acc: 0.8626 | Val Loss: 1.5160
# Early stopping at epoch 31
# Fold 1 Accuracy: 0.8630
# Fold 1 Macro F1: 0.8578
# Fold 1 Weighted F1: 0.8616
#
# ---------- Config 1 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.6458 | Val Acc: 0.7374 | Val Loss: 0.9639
# Epoch 005/80 | Train Acc: 0.8969 | Val Acc: 0.8143 | Val Loss: 0.9275
# Epoch 010/80 | Train Acc: 0.9669 | Val Acc: 0.8676 | Val Loss: 1.0185
# Epoch 015/80 | Train Acc: 0.9852 | Val Acc: 0.8693 | Val Loss: 1.2217
# Epoch 020/80 | Train Acc: 0.9896 | Val Acc: 0.8605 | Val Loss: 1.4100
# Epoch 025/80 | Train Acc: 0.9950 | Val Acc: 0.8697 | Val Loss: 1.3075
# Epoch 030/80 | Train Acc: 0.9962 | Val Acc: 0.8702 | Val Loss: 1.3962
# Epoch 035/80 | Train Acc: 0.9966 | Val Acc: 0.8639 | Val Loss: 1.4299
# Epoch 040/80 | Train Acc: 0.9977 | Val Acc: 0.8697 | Val Loss: 1.4367
# Epoch 045/80 | Train Acc: 0.9979 | Val Acc: 0.8723 | Val Loss: 1.4727
# Epoch 050/80 | Train Acc: 0.9977 | Val Acc: 0.8706 | Val Loss: 1.4644
# Epoch 055/80 | Train Acc: 0.9974 | Val Acc: 0.8702 | Val Loss: 1.5114
# Epoch 060/80 | Train Acc: 0.9980 | Val Acc: 0.8718 | Val Loss: 1.4594
# Epoch 065/80 | Train Acc: 0.9979 | Val Acc: 0.8693 | Val Loss: 1.4526
# Early stopping at epoch 68
# Fold 2 Accuracy: 0.8790
# Fold 2 Macro F1: 0.8691
# Fold 2 Weighted F1: 0.8794
#
# ---------- Config 1 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.6475 | Val Acc: 0.7385 | Val Loss: 0.7952
# Epoch 005/80 | Train Acc: 0.8979 | Val Acc: 0.8226 | Val Loss: 0.7161
# Epoch 010/80 | Train Acc: 0.9671 | Val Acc: 0.8680 | Val Loss: 0.7965
# Epoch 015/80 | Train Acc: 0.9776 | Val Acc: 0.8680 | Val Loss: 0.8725
# Epoch 020/80 | Train Acc: 0.9902 | Val Acc: 0.8844 | Val Loss: 0.9413
# Epoch 025/80 | Train Acc: 0.9945 | Val Acc: 0.8865 | Val Loss: 1.0251
# Epoch 030/80 | Train Acc: 0.9960 | Val Acc: 0.8844 | Val Loss: 1.0745
# Epoch 035/80 | Train Acc: 0.9960 | Val Acc: 0.8886 | Val Loss: 1.1002
# Epoch 040/80 | Train Acc: 0.9971 | Val Acc: 0.8844 | Val Loss: 1.1614
# Epoch 045/80 | Train Acc: 0.9979 | Val Acc: 0.8894 | Val Loss: 1.0808
# Epoch 050/80 | Train Acc: 0.9980 | Val Acc: 0.8827 | Val Loss: 1.1358
# Epoch 055/80 | Train Acc: 0.9977 | Val Acc: 0.8903 | Val Loss: 1.1039
# Epoch 060/80 | Train Acc: 0.9976 | Val Acc: 0.8890 | Val Loss: 1.0900
# Early stopping at epoch 62
# Fold 3 Accuracy: 0.8945
# Fold 3 Macro F1: 0.8865
# Fold 3 Weighted F1: 0.8948
#
# ---------- Config 1 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.6433 | Val Acc: 0.7486 | Val Loss: 0.8127
# Epoch 005/80 | Train Acc: 0.9040 | Val Acc: 0.8079 | Val Loss: 0.8189
# Epoch 010/80 | Train Acc: 0.9660 | Val Acc: 0.8373 | Val Loss: 0.9623
# Epoch 015/80 | Train Acc: 0.9799 | Val Acc: 0.8462 | Val Loss: 1.0942
# Epoch 020/80 | Train Acc: 0.9909 | Val Acc: 0.8520 | Val Loss: 1.2933
# Epoch 025/80 | Train Acc: 0.9946 | Val Acc: 0.8529 | Val Loss: 1.4785
# Epoch 030/80 | Train Acc: 0.9965 | Val Acc: 0.8575 | Val Loss: 1.5695
# Epoch 035/80 | Train Acc: 0.9973 | Val Acc: 0.8516 | Val Loss: 1.6349
# Epoch 040/80 | Train Acc: 0.9975 | Val Acc: 0.8592 | Val Loss: 1.5408
# Epoch 045/80 | Train Acc: 0.9980 | Val Acc: 0.8604 | Val Loss: 1.5944
# Early stopping at epoch 46
# Fold 4 Accuracy: 0.8625
# Fold 4 Macro F1: 0.8661
# Fold 4 Weighted F1: 0.8626
#
# ---------- Config 1 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.6257 | Val Acc: 0.7583 | Val Loss: 0.8553
# Epoch 005/80 | Train Acc: 0.8982 | Val Acc: 0.8415 | Val Loss: 0.6215
# Epoch 010/80 | Train Acc: 0.9442 | Val Acc: 0.8474 | Val Loss: 0.9142
# Epoch 015/80 | Train Acc: 0.9794 | Val Acc: 0.8739 | Val Loss: 1.0112
# Epoch 020/80 | Train Acc: 0.9904 | Val Acc: 0.8857 | Val Loss: 1.1821
# Epoch 025/80 | Train Acc: 0.9943 | Val Acc: 0.8903 | Val Loss: 1.2311
# Epoch 030/80 | Train Acc: 0.9959 | Val Acc: 0.8924 | Val Loss: 1.2758
# Epoch 035/80 | Train Acc: 0.9964 | Val Acc: 0.8890 | Val Loss: 1.3042
# Epoch 040/80 | Train Acc: 0.9980 | Val Acc: 0.8941 | Val Loss: 1.3430
# Epoch 045/80 | Train Acc: 0.9979 | Val Acc: 0.8886 | Val Loss: 1.4390
# Epoch 050/80 | Train Acc: 0.9979 | Val Acc: 0.8916 | Val Loss: 1.3959
# Epoch 055/80 | Train Acc: 0.9980 | Val Acc: 0.8894 | Val Loss: 1.4126
# Epoch 060/80 | Train Acc: 0.9978 | Val Acc: 0.8924 | Val Loss: 1.3656
# Early stopping at epoch 62
# Fold 5 Accuracy: 0.8958
# Fold 5 Macro F1: 0.8919
# Fold 5 Weighted F1: 0.8970
#
# ======================================================================
# Testing config 2/4
# {'cnn_channels_1': 96, 'cnn_channels_2': 160, 'cnn_channels_3': 224, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.35, 'lr': 0.001, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 2 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.6335 | Val Acc: 0.7395 | Val Loss: 0.7954
# Epoch 005/80 | Train Acc: 0.8918 | Val Acc: 0.8143 | Val Loss: 0.8873
# Epoch 010/80 | Train Acc: 0.9408 | Val Acc: 0.8294 | Val Loss: 1.1231
# Epoch 015/80 | Train Acc: 0.9778 | Val Acc: 0.8340 | Val Loss: 1.4243
# Epoch 020/80 | Train Acc: 0.9893 | Val Acc: 0.8492 | Val Loss: 1.4603
# Epoch 025/80 | Train Acc: 0.9933 | Val Acc: 0.8639 | Val Loss: 1.4543
# Epoch 030/80 | Train Acc: 0.9963 | Val Acc: 0.8626 | Val Loss: 1.5653
# Epoch 035/80 | Train Acc: 0.9970 | Val Acc: 0.8584 | Val Loss: 1.6682
# Epoch 040/80 | Train Acc: 0.9968 | Val Acc: 0.8634 | Val Loss: 1.5857
# Early stopping at epoch 41
# Fold 1 Accuracy: 0.8664
# Fold 1 Macro F1: 0.8602
# Fold 1 Weighted F1: 0.8647
#
# ---------- Config 2 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.6435 | Val Acc: 0.7437 | Val Loss: 0.8761
# Epoch 005/80 | Train Acc: 0.8925 | Val Acc: 0.8130 | Val Loss: 0.8120
# Epoch 010/80 | Train Acc: 0.9604 | Val Acc: 0.8546 | Val Loss: 0.9519
# Epoch 015/80 | Train Acc: 0.9767 | Val Acc: 0.8601 | Val Loss: 1.1579
# Epoch 020/80 | Train Acc: 0.9895 | Val Acc: 0.8618 | Val Loss: 1.2285
# Epoch 025/80 | Train Acc: 0.9940 | Val Acc: 0.8710 | Val Loss: 1.3685
# Epoch 030/80 | Train Acc: 0.9960 | Val Acc: 0.8718 | Val Loss: 1.4120
# Epoch 035/80 | Train Acc: 0.9967 | Val Acc: 0.8786 | Val Loss: 1.3891
# Epoch 040/80 | Train Acc: 0.9973 | Val Acc: 0.8769 | Val Loss: 1.4157
# Epoch 045/80 | Train Acc: 0.9974 | Val Acc: 0.8773 | Val Loss: 1.4470
# Early stopping at epoch 48
# Fold 2 Accuracy: 0.8845
# Fold 2 Macro F1: 0.8749
# Fold 2 Weighted F1: 0.8857
#
# ---------- Config 2 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.6317 | Val Acc: 0.7310 | Val Loss: 0.7852
# Epoch 005/80 | Train Acc: 0.8949 | Val Acc: 0.8293 | Val Loss: 0.6274
# Epoch 010/80 | Train Acc: 0.9606 | Val Acc: 0.8676 | Val Loss: 0.7654
# Epoch 015/80 | Train Acc: 0.9762 | Val Acc: 0.8651 | Val Loss: 0.9165
# Epoch 020/80 | Train Acc: 0.9882 | Val Acc: 0.8798 | Val Loss: 0.9921
# Epoch 025/80 | Train Acc: 0.9941 | Val Acc: 0.8764 | Val Loss: 1.0785
# Epoch 030/80 | Train Acc: 0.9956 | Val Acc: 0.8735 | Val Loss: 1.1930
# Early stopping at epoch 32
# Fold 3 Accuracy: 0.8802
# Fold 3 Macro F1: 0.8765
# Fold 3 Weighted F1: 0.8810
#
# ---------- Config 2 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.6312 | Val Acc: 0.7474 | Val Loss: 0.8249
# Epoch 005/80 | Train Acc: 0.8964 | Val Acc: 0.7915 | Val Loss: 0.7644
# Epoch 010/80 | Train Acc: 0.9431 | Val Acc: 0.8092 | Val Loss: 1.0979
# Epoch 015/80 | Train Acc: 0.9795 | Val Acc: 0.8323 | Val Loss: 1.3126
# Epoch 020/80 | Train Acc: 0.9892 | Val Acc: 0.8604 | Val Loss: 1.2465
# Epoch 025/80 | Train Acc: 0.9935 | Val Acc: 0.8567 | Val Loss: 1.4024
# Epoch 030/80 | Train Acc: 0.9958 | Val Acc: 0.8520 | Val Loss: 1.5443
# Epoch 035/80 | Train Acc: 0.9970 | Val Acc: 0.8487 | Val Loss: 1.7100
# Early stopping at epoch 35
# Fold 4 Accuracy: 0.8604
# Fold 4 Macro F1: 0.8627
# Fold 4 Weighted F1: 0.8605
#
# ---------- Config 2 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.6262 | Val Acc: 0.7533 | Val Loss: 0.8686
# Epoch 005/80 | Train Acc: 0.8891 | Val Acc: 0.8142 | Val Loss: 0.8075
# Epoch 010/80 | Train Acc: 0.9389 | Val Acc: 0.8516 | Val Loss: 0.9720
# Epoch 015/80 | Train Acc: 0.9771 | Val Acc: 0.8634 | Val Loss: 1.0258
# Epoch 020/80 | Train Acc: 0.9898 | Val Acc: 0.8743 | Val Loss: 1.3536
# Epoch 025/80 | Train Acc: 0.9921 | Val Acc: 0.8710 | Val Loss: 1.4746
# Epoch 030/80 | Train Acc: 0.9955 | Val Acc: 0.8777 | Val Loss: 1.5001
# Epoch 035/80 | Train Acc: 0.9972 | Val Acc: 0.8731 | Val Loss: 1.5940
# Epoch 040/80 | Train Acc: 0.9974 | Val Acc: 0.8777 | Val Loss: 1.5522
# Epoch 045/80 | Train Acc: 0.9979 | Val Acc: 0.8773 | Val Loss: 1.4999
# Epoch 050/80 | Train Acc: 0.9973 | Val Acc: 0.8785 | Val Loss: 1.5670
# Epoch 055/80 | Train Acc: 0.9981 | Val Acc: 0.8831 | Val Loss: 1.5221
# Epoch 060/80 | Train Acc: 0.9985 | Val Acc: 0.8794 | Val Loss: 1.5646
# Epoch 065/80 | Train Acc: 0.9981 | Val Acc: 0.8768 | Val Loss: 1.5863
# Epoch 070/80 | Train Acc: 0.9979 | Val Acc: 0.8806 | Val Loss: 1.5427
# Early stopping at epoch 72
# Fold 5 Accuracy: 0.8840
# Fold 5 Macro F1: 0.8819
# Fold 5 Weighted F1: 0.8839
#
# ======================================================================
# Testing config 3/4
# {'cnn_channels_1': 128, 'cnn_channels_2': 160, 'cnn_channels_3': 224, 'hidden_size': 256, 'num_layers': 1, 'dropout': 0.35, 'lr': 0.0005, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 3 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.6550 | Val Acc: 0.7609 | Val Loss: 0.8445
# Epoch 005/80 | Train Acc: 0.9098 | Val Acc: 0.8256 | Val Loss: 0.7407
# Epoch 010/80 | Train Acc: 0.9560 | Val Acc: 0.8403 | Val Loss: 0.9711
# Epoch 015/80 | Train Acc: 0.9848 | Val Acc: 0.8613 | Val Loss: 1.2711
# Epoch 020/80 | Train Acc: 0.9932 | Val Acc: 0.8618 | Val Loss: 1.4721
# Epoch 025/80 | Train Acc: 0.9965 | Val Acc: 0.8622 | Val Loss: 1.5699
# Epoch 030/80 | Train Acc: 0.9981 | Val Acc: 0.8681 | Val Loss: 1.4990
# Epoch 035/80 | Train Acc: 0.9982 | Val Acc: 0.8626 | Val Loss: 1.6007
# Epoch 040/80 | Train Acc: 0.9986 | Val Acc: 0.8676 | Val Loss: 1.6429
# Epoch 045/80 | Train Acc: 0.9990 | Val Acc: 0.8681 | Val Loss: 1.5645
# Epoch 050/80 | Train Acc: 0.9987 | Val Acc: 0.8672 | Val Loss: 1.5905
# Epoch 055/80 | Train Acc: 0.9988 | Val Acc: 0.8710 | Val Loss: 1.5954
# Epoch 060/80 | Train Acc: 0.9987 | Val Acc: 0.8676 | Val Loss: 1.5562
# Epoch 065/80 | Train Acc: 0.9988 | Val Acc: 0.8664 | Val Loss: 1.5283
# Early stopping at epoch 69
# Fold 1 Accuracy: 0.8714
# Fold 1 Macro F1: 0.8656
# Fold 1 Weighted F1: 0.8686
#
# ---------- Config 3 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.6678 | Val Acc: 0.7563 | Val Loss: 0.8292
# Epoch 005/80 | Train Acc: 0.9152 | Val Acc: 0.8454 | Val Loss: 0.7390
# Epoch 010/80 | Train Acc: 0.9780 | Val Acc: 0.8609 | Val Loss: 1.0222
# Epoch 015/80 | Train Acc: 0.9904 | Val Acc: 0.8702 | Val Loss: 1.3196
# Epoch 020/80 | Train Acc: 0.9927 | Val Acc: 0.8672 | Val Loss: 1.3757
# Epoch 025/80 | Train Acc: 0.9968 | Val Acc: 0.8794 | Val Loss: 1.4102
# Epoch 030/80 | Train Acc: 0.9980 | Val Acc: 0.8697 | Val Loss: 1.4207
# Early stopping at epoch 34
# Fold 2 Accuracy: 0.8866
# Fold 2 Macro F1: 0.8787
# Fold 2 Weighted F1: 0.8866
#
# ---------- Config 3 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.6669 | Val Acc: 0.7730 | Val Loss: 0.7224
# Epoch 005/80 | Train Acc: 0.9159 | Val Acc: 0.8285 | Val Loss: 0.7696
# Epoch 010/80 | Train Acc: 0.9759 | Val Acc: 0.8625 | Val Loss: 0.8127
# Epoch 015/80 | Train Acc: 0.9904 | Val Acc: 0.8789 | Val Loss: 0.8934
# Epoch 020/80 | Train Acc: 0.9925 | Val Acc: 0.8697 | Val Loss: 1.0565
# Epoch 025/80 | Train Acc: 0.9960 | Val Acc: 0.8781 | Val Loss: 1.0359
# Epoch 030/80 | Train Acc: 0.9974 | Val Acc: 0.8840 | Val Loss: 1.1005
# Epoch 035/80 | Train Acc: 0.9982 | Val Acc: 0.8680 | Val Loss: 1.2372
# Epoch 040/80 | Train Acc: 0.9988 | Val Acc: 0.8777 | Val Loss: 1.1038
# Epoch 045/80 | Train Acc: 0.9986 | Val Acc: 0.8756 | Val Loss: 1.1518
# Early stopping at epoch 45
# Fold 3 Accuracy: 0.8840
# Fold 3 Macro F1: 0.8790
# Fold 3 Weighted F1: 0.8839
#
# ---------- Config 3 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.6526 | Val Acc: 0.7289 | Val Loss: 0.8257
# Epoch 005/80 | Train Acc: 0.9140 | Val Acc: 0.8100 | Val Loss: 0.8219
# Epoch 010/80 | Train Acc: 0.9575 | Val Acc: 0.8201 | Val Loss: 1.0868
# Epoch 015/80 | Train Acc: 0.9848 | Val Acc: 0.8453 | Val Loss: 1.2571
# Epoch 020/80 | Train Acc: 0.9939 | Val Acc: 0.8600 | Val Loss: 1.1790
# Epoch 025/80 | Train Acc: 0.9957 | Val Acc: 0.8714 | Val Loss: 1.3325
# Epoch 030/80 | Train Acc: 0.9973 | Val Acc: 0.8659 | Val Loss: 1.4386
# Epoch 035/80 | Train Acc: 0.9985 | Val Acc: 0.8676 | Val Loss: 1.4697
# Epoch 040/80 | Train Acc: 0.9987 | Val Acc: 0.8634 | Val Loss: 1.4087
# Epoch 045/80 | Train Acc: 0.9985 | Val Acc: 0.8655 | Val Loss: 1.4497
# Early stopping at epoch 48
# Fold 4 Accuracy: 0.8722
# Fold 4 Macro F1: 0.8739
# Fold 4 Weighted F1: 0.8723
#
# ---------- Config 3 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.6395 | Val Acc: 0.7810 | Val Loss: 0.7517
# Epoch 005/80 | Train Acc: 0.9048 | Val Acc: 0.8546 | Val Loss: 0.6698
# Epoch 010/80 | Train Acc: 0.9709 | Val Acc: 0.8806 | Val Loss: 0.9331
# Epoch 015/80 | Train Acc: 0.9826 | Val Acc: 0.8840 | Val Loss: 0.9500
# Epoch 020/80 | Train Acc: 0.9927 | Val Acc: 0.8802 | Val Loss: 1.1922
# Epoch 025/80 | Train Acc: 0.9955 | Val Acc: 0.8924 | Val Loss: 1.1959
# Epoch 030/80 | Train Acc: 0.9972 | Val Acc: 0.8886 | Val Loss: 1.2546
# Epoch 035/80 | Train Acc: 0.9980 | Val Acc: 0.8966 | Val Loss: 1.2433
# Epoch 040/80 | Train Acc: 0.9985 | Val Acc: 0.8907 | Val Loss: 1.2858
# Epoch 045/80 | Train Acc: 0.9979 | Val Acc: 0.8890 | Val Loss: 1.2823
# Epoch 050/80 | Train Acc: 0.9985 | Val Acc: 0.8869 | Val Loss: 1.3365
# Early stopping at epoch 50
# Fold 5 Accuracy: 0.8966
# Fold 5 Macro F1: 0.8937
# Fold 5 Weighted F1: 0.8970
#
# ======================================================================
# Testing config 4/4
# {'cnn_channels_1': 96, 'cnn_channels_2': 128, 'cnn_channels_3': 192, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.4, 'lr': 0.0005, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 4 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.6076 | Val Acc: 0.7391 | Val Loss: 0.8912
# Epoch 005/80 | Train Acc: 0.8979 | Val Acc: 0.8046 | Val Loss: 0.8772
# Epoch 010/80 | Train Acc: 0.9594 | Val Acc: 0.8672 | Val Loss: 0.9614
# Epoch 015/80 | Train Acc: 0.9767 | Val Acc: 0.8496 | Val Loss: 1.2940
# Epoch 020/80 | Train Acc: 0.9899 | Val Acc: 0.8592 | Val Loss: 1.5245
# Epoch 025/80 | Train Acc: 0.9941 | Val Acc: 0.8668 | Val Loss: 1.5168
# Epoch 030/80 | Train Acc: 0.9953 | Val Acc: 0.8676 | Val Loss: 1.4765
# Epoch 035/80 | Train Acc: 0.9967 | Val Acc: 0.8718 | Val Loss: 1.5610
# Epoch 040/80 | Train Acc: 0.9971 | Val Acc: 0.8697 | Val Loss: 1.6033
# Epoch 045/80 | Train Acc: 0.9965 | Val Acc: 0.8693 | Val Loss: 1.5669
# Epoch 050/80 | Train Acc: 0.9977 | Val Acc: 0.8723 | Val Loss: 1.5263
# Early stopping at epoch 51
# Fold 1 Accuracy: 0.8748
# Fold 1 Macro F1: 0.8688
# Fold 1 Weighted F1: 0.8724
#
# ---------- Config 4 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.6031 | Val Acc: 0.7025 | Val Loss: 1.0170
# Epoch 005/80 | Train Acc: 0.8923 | Val Acc: 0.8324 | Val Loss: 0.7318
# Epoch 010/80 | Train Acc: 0.9428 | Val Acc: 0.8630 | Val Loss: 0.9167
# Epoch 015/80 | Train Acc: 0.9778 | Val Acc: 0.8639 | Val Loss: 1.1955
# Epoch 020/80 | Train Acc: 0.9906 | Val Acc: 0.8693 | Val Loss: 1.4761
# Epoch 025/80 | Train Acc: 0.9932 | Val Acc: 0.8731 | Val Loss: 1.4123
# Epoch 030/80 | Train Acc: 0.9954 | Val Acc: 0.8782 | Val Loss: 1.5517
# Epoch 035/80 | Train Acc: 0.9970 | Val Acc: 0.8727 | Val Loss: 1.5989
# Epoch 040/80 | Train Acc: 0.9979 | Val Acc: 0.8723 | Val Loss: 1.6622
# Epoch 045/80 | Train Acc: 0.9977 | Val Acc: 0.8723 | Val Loss: 1.7045
# Early stopping at epoch 46
# Fold 2 Accuracy: 0.8828
# Fold 2 Macro F1: 0.8720
# Fold 2 Weighted F1: 0.8831
#
# ---------- Config 4 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.6204 | Val Acc: 0.7360 | Val Loss: 0.8127
# Epoch 005/80 | Train Acc: 0.8942 | Val Acc: 0.8125 | Val Loss: 0.6743
# Epoch 010/80 | Train Acc: 0.9448 | Val Acc: 0.8655 | Val Loss: 0.6429
# Epoch 015/80 | Train Acc: 0.9642 | Val Acc: 0.8609 | Val Loss: 0.8072
# Epoch 020/80 | Train Acc: 0.9852 | Val Acc: 0.8777 | Val Loss: 0.9603
# Epoch 025/80 | Train Acc: 0.9936 | Val Acc: 0.8815 | Val Loss: 1.0712
# Epoch 030/80 | Train Acc: 0.9960 | Val Acc: 0.8693 | Val Loss: 1.2367
# Epoch 035/80 | Train Acc: 0.9972 | Val Acc: 0.8752 | Val Loss: 1.2962
# Early stopping at epoch 38
# Fold 3 Accuracy: 0.8815
# Fold 3 Macro F1: 0.8784
# Fold 3 Weighted F1: 0.8827
#
# ---------- Config 4 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.6236 | Val Acc: 0.7705 | Val Loss: 0.7461
# Epoch 005/80 | Train Acc: 0.8949 | Val Acc: 0.8176 | Val Loss: 0.8133
# Epoch 010/80 | Train Acc: 0.9673 | Val Acc: 0.8314 | Val Loss: 1.2150
# Epoch 015/80 | Train Acc: 0.9856 | Val Acc: 0.8457 | Val Loss: 1.3538
# Epoch 020/80 | Train Acc: 0.9892 | Val Acc: 0.8579 | Val Loss: 1.2798
# Epoch 025/80 | Train Acc: 0.9946 | Val Acc: 0.8487 | Val Loss: 1.5984
# Epoch 030/80 | Train Acc: 0.9956 | Val Acc: 0.8432 | Val Loss: 1.7274
# Epoch 035/80 | Train Acc: 0.9971 | Val Acc: 0.8516 | Val Loss: 1.7654
# Early stopping at epoch 35
# Fold 4 Accuracy: 0.8579
# Fold 4 Macro F1: 0.8596
# Fold 4 Weighted F1: 0.8576
#
# ---------- Config 4 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.6080 | Val Acc: 0.7335 | Val Loss: 0.8939
# Epoch 005/80 | Train Acc: 0.8977 | Val Acc: 0.8344 | Val Loss: 0.7658
# Epoch 010/80 | Train Acc: 0.9629 | Val Acc: 0.8651 | Val Loss: 0.8703
# Epoch 015/80 | Train Acc: 0.9785 | Val Acc: 0.8701 | Val Loss: 0.9634
# Epoch 020/80 | Train Acc: 0.9906 | Val Acc: 0.8819 | Val Loss: 1.1395
# Epoch 025/80 | Train Acc: 0.9941 | Val Acc: 0.8852 | Val Loss: 1.2632
# Epoch 030/80 | Train Acc: 0.9960 | Val Acc: 0.8840 | Val Loss: 1.2629
# Epoch 035/80 | Train Acc: 0.9963 | Val Acc: 0.8873 | Val Loss: 1.3133
# Epoch 040/80 | Train Acc: 0.9973 | Val Acc: 0.8861 | Val Loss: 1.3146
# Epoch 045/80 | Train Acc: 0.9972 | Val Acc: 0.8890 | Val Loss: 1.3403
# Epoch 050/80 | Train Acc: 0.9972 | Val Acc: 0.8861 | Val Loss: 1.3587
# Epoch 055/80 | Train Acc: 0.9978 | Val Acc: 0.8882 | Val Loss: 1.3398
# Epoch 060/80 | Train Acc: 0.9979 | Val Acc: 0.8916 | Val Loss: 1.2952
# Epoch 065/80 | Train Acc: 0.9974 | Val Acc: 0.8890 | Val Loss: 1.3599
# Epoch 070/80 | Train Acc: 0.9976 | Val Acc: 0.8852 | Val Loss: 1.3840
# Epoch 075/80 | Train Acc: 0.9977 | Val Acc: 0.8886 | Val Loss: 1.3184
# Early stopping at epoch 75
# Fold 5 Accuracy: 0.8916
# Fold 5 Macro F1: 0.8910
# Fold 5 Weighted F1: 0.8920
#
# ================ BEST HYPERPARAMETERS ================
# Best config: {'cnn_channels_1': 128, 'cnn_channels_2': 160, 'cnn_channels_3': 224, 'hidden_size': 256, 'num_layers': 1, 'dropout': 0.35, 'lr': 0.0005, 'weight_decay': 1e-05}
# Best mean CV macro F1: 0.8781845270127354
# Best mean CV accuracy: 0.882155697083373
#    config_id  cnn_channels_1  cnn_channels_2  cnn_channels_3  hidden_size  \
# 0          1              96             128             192          128
# 1          2              96             160             224          128
# 2          3             128             160             224          256
# 3          4              96             128             192          128
#
#    num_layers  dropout      lr  weight_decay  mean_accuracy  mean_macro_f1  \
# 0           1     0.30  0.0010       0.00001       0.878962       0.874281
# 1           1     0.35  0.0010       0.00001       0.875095       0.871239
# 2           1     0.35  0.0005       0.00001       0.882156       0.878185
# 3           2     0.40  0.0005       0.00001       0.877700       0.873947
#
#    mean_weighted_f1
# 0          0.879081
# 1          0.875152
# 2          0.881679
# 3          0.877549

# %%
# ============================================================
# 9. Save best-config CV results + training graphs
# ============================================================

results_df = pd.DataFrame({
    "fold": list(range(1, len(best_fold_accuracies) + 1)),
    "accuracy": best_fold_accuracies,
    "macro_f1": best_fold_macro_f1,
    "weighted_f1": best_fold_weighted_f1
})

CV_RESULTS_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_lstm_best_config_cv_results.csv"
)

results_df.to_csv(CV_RESULTS_PATH, index=False)
display(results_df)

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_acc"], label="train_acc")
plt.plot(best_history["val_acc"], label="val_acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title(f"PyTorch CNN + LSTM Accuracy - Best Config, Fold {best_fold}")
plt.legend()

ACC_PLOT_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_lstm_best_config_accuracy.png"
)

plt.savefig(ACC_PLOT_PATH, dpi=200, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_loss"], label="train_loss")
plt.plot(best_history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"PyTorch CNN + LSTM Loss - Best Config, Fold {best_fold}")
plt.legend()

LOSS_PLOT_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_lstm_best_config_loss.png"
)

plt.savefig(LOSS_PLOT_PATH, dpi=200, bbox_inches="tight")
plt.show()

print("Saved:", CV_RESULTS_PATH)
print("Saved:", ACC_PLOT_PATH)
print("Saved:", LOSS_PLOT_PATH)
# Out:
#    fold  accuracy  macro_f1  weighted_f1
# 0     1  0.871429  0.865571     0.868645
# 1     2  0.886555  0.878697     0.886607
# 2     3  0.883985  0.879024     0.883870
# 3     4  0.872215  0.873918     0.872304
# 4     5  0.896595  0.893713     0.896967
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_lstm_coreml/torch_cnn_lstm_best_config_cv_results.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_lstm_coreml/torch_cnn_lstm_best_config_accuracy.png
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_lstm_coreml/torch_cnn_lstm_best_config_loss.png

# %%
# ============================================================
# 10. CV classification report + confusion matrix for best config
# ============================================================

overall_report = classification_report(
    best_all_true,
    best_all_pred,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

report_df = pd.DataFrame(overall_report).transpose()

REPORT_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_lstm_best_config_cv_classification_report.csv"
)

report_df.to_csv(REPORT_PATH)
display(report_df)

cm = confusion_matrix(
    best_all_true,
    best_all_pred
)

plt.figure(figsize=(12, 10))
plt.imshow(cm)
plt.title("PyTorch CNN + LSTM Best Config CV Confusion Matrix")
plt.colorbar()

plt.xticks(
    range(len(label_names)),
    label_names,
    rotation=90
)

plt.yticks(
    range(len(label_names)),
    label_names
)

plt.tight_layout()

CM_PNG_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_lstm_best_config_cv_confusion_matrix.png"
)

plt.savefig(CM_PNG_PATH, dpi=200, bbox_inches="tight")
plt.show()

np.save(
    os.path.join(
        OUTPUT_RESULT_DIR,
        "torch_cnn_lstm_best_config_cv_confusion_matrix.npy"
    ),
    cm
)

print("Saved:", REPORT_PATH)
print("Saved:", CM_PNG_PATH)
# Out:
#                      precision    recall  f1-score       support
# barbell biceps curl   0.764865  0.787204  0.775874    719.000000
# bench press           0.699793  0.656311  0.677355    515.000000
# chest fly machine     0.928571  0.950715  0.939513    629.000000
# deadlift              0.832432  0.866792  0.849265    533.000000
# decline bench press   0.864159  0.892125  0.877919    927.000000
# hammer curl           0.837057  0.851604  0.844268    748.000000
# hip thrust            0.929254  0.916981  0.923077    530.000000
# incline bench press   0.862550  0.915433  0.888205    473.000000
# lat pulldown          0.862162  0.852941  0.857527    374.000000
# lateral raise         0.931116  0.892938  0.911628    439.000000
# leg extension         0.946552  0.894137  0.919598    614.000000
# leg raises            0.952234  0.955178  0.953704    647.000000
# pull Up               0.920792  0.892800  0.906580    625.000000
# push-up               0.935172  0.969957  0.952247    699.000000
# romanian deadlift     0.842105  0.806202  0.823762    516.000000
# russian twist         0.973154  0.939525  0.956044    463.000000
# shoulder press        0.847150  0.874332  0.860526    374.000000
# squat                 0.944862  0.954430  0.949622    790.000000
# t bar row             0.881757  0.890785  0.886248    586.000000
# tricep Pushdown       0.825397  0.820189  0.822785    317.000000
# tricep dips           0.916905  0.844327  0.879121    379.000000
# accuracy              0.882155  0.882155  0.882155      0.882155
# macro avg             0.880859  0.877377  0.878803  11897.000000
# weighted avg          0.882380  0.882155  0.881981  11897.000000
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_lstm_coreml/torch_cnn_lstm_best_config_cv_classification_report.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_lstm_coreml/torch_cnn_lstm_best_config_cv_confusion_matrix.png

# %%
# ============================================================
# 11. Retrain final model on ALL verified data
# ============================================================
final_scaler = StandardScaler()

n, t, f = X_verified.shape

X_verified_flat = X_verified.reshape(-1, f)

X_verified_scaled = final_scaler.fit_transform(
    X_verified_flat
).reshape(n, t, f).astype(np.float32)

X_verified_aug, y_verified_aug = make_augmented_training_data(
    X_verified_scaled,
    y_verified,
    copies=2
)

train_dataset = TensorDataset(
    torch.FloatTensor(X_verified_aug),
    torch.LongTensor(y_verified_aug)
)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

final_model = WorkoutClassifierCNNLSTM(
    input_size=FEATURE_SIZE,
    cnn_channels_1=best_config["cnn_channels_1"],
    cnn_channels_2=best_config["cnn_channels_2"],
    cnn_channels_3=best_config["cnn_channels_3"],
    hidden_size=best_config["hidden_size"],
    num_layers=best_config["num_layers"],
    num_classes=num_classes,
    dropout=best_config["dropout"]
).to(DEVICE)

class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_verified_aug),
    y=y_verified_aug
)

class_weights_tensor = torch.FloatTensor(
    class_weights_arr
).to(DEVICE)

criterion = nn.CrossEntropyLoss(
    weight=class_weights_tensor
)

optimizer = optim.Adam(
    final_model.parameters(),
    lr=best_config["lr"],
    weight_decay=best_config["weight_decay"]
)

FINAL_EPOCHS = 40

final_history = {
    "train_loss": [],
    "train_acc": []
}

for epoch in range(1, FINAL_EPOCHS + 1):
    train_loss, train_acc = train_one_epoch(
        final_model,
        train_loader,
        criterion,
        optimizer,
        DEVICE
    )

    final_history["train_loss"].append(train_loss)
    final_history["train_acc"].append(train_acc)

    if epoch == 1 or epoch % 5 == 0:
        print(
            f"Final Epoch {epoch:03d}/{FINAL_EPOCHS} | "
            f"Loss: {train_loss:.4f} | "
            f"Acc: {train_acc:.4f}"
        )

final_model.eval()
# Out:
# Final Epoch 001/40 | Loss: 1.0175 | Acc: 0.6703
# Final Epoch 005/40 | Loss: 0.2611 | Acc: 0.9137
# Final Epoch 010/40 | Loss: 0.1457 | Acc: 0.9569
# Final Epoch 015/40 | Loss: 0.1000 | Acc: 0.9730
# Final Epoch 020/40 | Loss: 0.0713 | Acc: 0.9803
# Final Epoch 025/40 | Loss: 0.0646 | Acc: 0.9845
# Final Epoch 030/40 | Loss: 0.0523 | Acc: 0.9862
# Final Epoch 035/40 | Loss: 0.0449 | Acc: 0.9887
# Final Epoch 040/40 | Loss: 0.0405 | Acc: 0.9902
# WorkoutClassifierCNNLSTM(
#   (conv_block): Sequential(
#     (0): Conv1d(300, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.21, inplace=False)
#     (4): Conv1d(128, 160, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.24499999999999997, inplace=False)
#     (8): Conv1d(160, 224, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#   )
#   (lstm): LSTM(224, 256, batch_first=True, bidirectional=True)
#   (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (attention): Linear(in_features=512, out_features=1, bias=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.35, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.35, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )

# %%
# ============================================================
# 12. Evaluate final model on official test split
# ============================================================
X_test_scaled = scale_with_existing_scaler(
    X_test,
    final_scaler
)

test_dataset = TensorDataset(
    torch.FloatTensor(X_test_scaled),
    torch.LongTensor(y_test)
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loss, test_acc, test_preds, test_labels = evaluate(
    final_model,
    test_loader,
    criterion,
    DEVICE
)

test_macro = f1_score(
    test_labels,
    test_preds,
    average="macro"
)

test_weighted = f1_score(
    test_labels,
    test_preds,
    average="weighted"
)

print("Official Test Accuracy:", test_acc)
print("Official Test Macro F1:", test_macro)
print("Official Test Weighted F1:", test_weighted)

print(classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0
))
# Out:
# Official Test Accuracy: 0.576952822892498
# Official Test Macro F1: 0.5762289711682426
# Official Test Weighted F1: 0.5823624831230626
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.33      0.76      0.46        49
#         bench press       0.21      0.72      0.33        36
#   chest fly machine       0.82      0.71      0.76        89
#            deadlift       0.69      0.69      0.69       156
# decline bench press       0.33      0.45      0.38        83
#         hammer curl       0.05      0.02      0.03        49
#          hip thrust       0.73      0.51      0.61        70
# incline bench press       0.28      0.17      0.21        77
#        lat pulldown       0.71      0.35      0.47        34
#       lateral raise       0.73      0.42      0.54        26
#       leg extension       0.90      0.97      0.93        36
#          leg raises       0.88      0.64      0.74        70
#             pull Up       0.84      0.82      0.83        62
#             push-up       0.87      0.41      0.56        82
#   romanian deadlift       0.27      0.32      0.29        50
#       russian twist       0.60      0.96      0.74        28
#      shoulder press       0.97      0.55      0.70        69
#               squat       0.57      0.64      0.60        55
#           t bar row       0.48      0.49      0.48        72
#     tricep Pushdown       0.77      1.00      0.87        27
#         tricep dips       0.94      0.82      0.88        73
#
#            accuracy                           0.58      1293
#           macro avg       0.62      0.59      0.58      1293
#        weighted avg       0.63      0.58      0.58      1293

# %%
# ============================================================
# 13. Save official test report + confusion matrix
# ============================================================
test_report = classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

test_report_df = pd.DataFrame(
    test_report
).transpose()

TEST_REPORT_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_lstm_official_test_report.csv"
)

test_report_df.to_csv(
    TEST_REPORT_PATH
)

display(test_report_df)

test_cm = confusion_matrix(
    test_labels,
    test_preds
)

plt.figure(figsize=(12, 10))
plt.imshow(test_cm)
plt.title("PyTorch CNN + LSTM Official Test Confusion Matrix")
plt.colorbar()

plt.xticks(
    range(len(label_names)),
    label_names,
    rotation=90
)

plt.yticks(
    range(len(label_names)),
    label_names
)

plt.tight_layout()

TEST_CM_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_lstm_official_test_confusion_matrix.png"
)

plt.savefig(
    TEST_CM_PATH,
    dpi=200,
    bbox_inches="tight"
)

plt.show()

np.save(
    os.path.join(OUTPUT_RESULT_DIR, "torch_cnn_lstm_official_test_confusion_matrix.npy"),
    test_cm
)

print("Saved:", TEST_REPORT_PATH)
print("Saved:", TEST_CM_PATH)
# Out:
#                      precision    recall  f1-score      support
# barbell biceps curl   0.330357  0.755102  0.459627    49.000000
# bench press           0.209677  0.722222  0.325000    36.000000
# chest fly machine     0.818182  0.707865  0.759036    89.000000
# deadlift              0.690323  0.685897  0.688103   156.000000
# decline bench press   0.327434  0.445783  0.377551    83.000000
# hammer curl           0.052632  0.020408  0.029412    49.000000
# hip thrust            0.734694  0.514286  0.605042    70.000000
# incline bench press   0.282609  0.168831  0.211382    77.000000
# lat pulldown          0.705882  0.352941  0.470588    34.000000
# lateral raise         0.733333  0.423077  0.536585    26.000000
# leg extension         0.897436  0.972222  0.933333    36.000000
# leg raises            0.882353  0.642857  0.743802    70.000000
# pull Up               0.836066  0.822581  0.829268    62.000000
# push-up               0.871795  0.414634  0.561983    82.000000
# romanian deadlift     0.271186  0.320000  0.293578    50.000000
# russian twist         0.600000  0.964286  0.739726    28.000000
# shoulder press        0.974359  0.550725  0.703704    69.000000
# squat                 0.573770  0.636364  0.603448    55.000000
# t bar row             0.479452  0.486111  0.482759    72.000000
# tricep Pushdown       0.771429  1.000000  0.870968    27.000000
# tricep dips           0.937500  0.821918  0.875912    73.000000
# accuracy              0.576953  0.576953  0.576953     0.576953
# macro avg             0.618118  0.591815  0.576229  1293.000000
# weighted avg          0.634637  0.576953  0.582362  1293.000000
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_lstm_coreml/torch_cnn_lstm_official_test_report.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_lstm_coreml/torch_cnn_lstm_official_test_confusion_matrix.png

# %%
# ============================================================
# 14. Save PyTorch checkpoint + scaler + labels
# ============================================================

final_model_cpu = final_model.cpu()

CHECKPOINT_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "best_workout_cnn_lstm_model.pth"
)

checkpoint = {
    "model_state_dict": final_model_cpu.state_dict(),

    "hyperparams": {
        "input_size": FEATURE_SIZE,
        "cnn_channels_1": best_config["cnn_channels_1"],
        "cnn_channels_2": best_config["cnn_channels_2"],
        "cnn_channels_3": best_config["cnn_channels_3"],
        "hidden_size": best_config["hidden_size"],
        "num_layers": best_config["num_layers"],
        "num_classes": num_classes,
        "dropout": best_config["dropout"],
        "sequence_length": SEQUENCE_LENGTH,
        "lr": best_config["lr"],
        "weight_decay": best_config["weight_decay"]
    },

    "best_config": best_config,
    "label_names": label_names,
    "test_accuracy": test_acc,
    "test_macro_f1": test_macro,
    "test_weighted_f1": test_weighted
}

torch.save(checkpoint, CHECKPOINT_PATH)

SCALER_JSON_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "mediapipe_scaler.json"
)

with open(SCALER_JSON_PATH, "w") as f:
    json.dump({
        "mean": final_scaler.mean_.tolist(),
        "scale": final_scaler.scale_.tolist()
    }, f)

LABEL_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "label_names.json"
)

with open(LABEL_PATH, "w") as f:
    json.dump(label_names, f)

print("Saved checkpoint:", CHECKPOINT_PATH)
print("Saved scaler:", SCALER_JSON_PATH)
print("Saved labels:", LABEL_PATH)
# Out:
# Saved checkpoint: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_lstm_coreml/best_workout_cnn_lstm_model.pth
# Saved scaler: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_lstm_coreml/mediapipe_scaler.json
# Saved labels: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_lstm_coreml/label_names.json

# %%
# ============================================================
# 15. Convert final PyTorch CNN + LSTM model to CoreML
# ============================================================

export_model = WorkoutClassifierCNNLSTM(
    input_size=FEATURE_SIZE,
    cnn_channels_1=checkpoint["hyperparams"]["cnn_channels_1"],
    cnn_channels_2=checkpoint["hyperparams"]["cnn_channels_2"],
    cnn_channels_3=checkpoint["hyperparams"]["cnn_channels_3"],
    hidden_size=checkpoint["hyperparams"]["hidden_size"],
    num_layers=checkpoint["hyperparams"]["num_layers"],
    num_classes=checkpoint["hyperparams"]["num_classes"],
    dropout=checkpoint["hyperparams"]["dropout"]
)

export_model.load_state_dict(
    checkpoint["model_state_dict"]
)

export_model.eval()

example_input = torch.rand(
    1,
    SEQUENCE_LENGTH,
    FEATURE_SIZE
)

with torch.no_grad():
    example_output = export_model(example_input)

print("Example input:", example_input.shape)
print("Example output:", example_output.shape)

traced_model = torch.jit.trace(
    export_model,
    example_input
)

coreml_model = ct.convert(
    traced_model,
    inputs=[
        ct.TensorType(
            name="input",
            shape=example_input.shape
        )
    ],
    outputs=[
        ct.TensorType(
            name="logits"
        )
    ],
    convert_to="mlprogram",
    minimum_deployment_target=ct.target.iOS15
)

COREML_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "WorkoutClassifierCNNLSTM.mlpackage"
)

coreml_model.save(COREML_PATH)

print("Saved CoreML model:", COREML_PATH)
# Out:
# Example input: torch.Size([1, 48, 300])
# Example output: torch.Size([1, 21])
# Converting PyTorch Frontend ==> MIL Ops:  99%|█████████▉| 79/80 [00:00<00:00, 1404.84 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 190.05 passes/s]
# Running MIL default pipeline: 100%|██████████| 95/95 [00:00<00:00, 197.34 passes/s]
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 549.42 passes/s]
# Saved CoreML model: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_lstm_coreml/WorkoutClassifierCNNLSTM.mlpackage
