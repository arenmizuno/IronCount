# %% [markdown]
# # MediaPipe + CNN Classification Model
# ## ADSP 32023 - Advanced Computer Vision Using Deep Learning
# ## Spring 2026

# %%
# ============================================================
# 0. Install packages
# ============================================================
# !pip install -q torch torchvision torchaudio coremltools scikit-learn matplotlib pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.3 MB/s eta 0:00:00

# %%
# ============================================================
# 1. Imports
# ============================================================
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight
from google.colab import drive

import coremltools as ct

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# WARNING:coremltools:scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# WARNING:coremltools:XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING:coremltools:TensorFlow version 2.20.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# WARNING:coremltools:Torch version 2.11.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# Device: cuda

# %%
# ============================================================
# 2. Paths + config
# ============================================================
drive.mount("/content/drive")
PROJECT_DIR = "/content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/"

SAVE_DIR = os.path.join(PROJECT_DIR, "data", "preprocessed")
MODEL_DIR = os.path.join(PROJECT_DIR, "models")
GRAPH_DIR = os.path.join(PROJECT_DIR, "graphs")
RESULT_DIR = os.path.join(PROJECT_DIR, "data")
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(RESULT_DIR, exist_ok=True)

EXPERIMENT_NAME = "torch_cnn_coreml"
OUTPUT_MODEL_DIR = os.path.join(MODEL_DIR, EXPERIMENT_NAME)
OUTPUT_GRAPH_DIR = os.path.join(GRAPH_DIR, EXPERIMENT_NAME)
OUTPUT_RESULT_DIR = os.path.join(RESULT_DIR, EXPERIMENT_NAME)
os.makedirs(OUTPUT_MODEL_DIR, exist_ok=True)
os.makedirs(OUTPUT_GRAPH_DIR, exist_ok=True)
os.makedirs(OUTPUT_RESULT_DIR, exist_ok=True)

BATCH_SIZE = 32
EPOCHS = 80
N_SPLITS = 5

DROPOUT = 0.30
LR = 1e-3
WEIGHT_DECAY = 1e-5
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# 3. Load new extracted MediaPipe data
# ============================================================
X_verified = np.load(os.path.join(SAVE_DIR, "X_verified_mediapipe.npy"))
y_verified = np.load(os.path.join(SAVE_DIR, "y_verified.npy"))

X_test = np.load(os.path.join(SAVE_DIR, "X_test_mediapipe.npy"))
y_test = np.load(os.path.join(SAVE_DIR, "y_test.npy"))

kept_verified_df = pd.read_csv(os.path.join(SAVE_DIR, "kept_verified_mediapipe_dataset.csv"))

with open(os.path.join(SAVE_DIR, "label_names.json"), "r") as f:
    label_names = json.load(f)

num_classes = len(label_names)
SEQUENCE_LENGTH = X_verified.shape[1]
FEATURE_SIZE = X_verified.shape[2]

print("X_verified:", X_verified.shape)
print("X_test:", X_test.shape)
print("num_classes:", num_classes)
print(label_names)
# Out:
# X_verified: (11897, 48, 300)
# X_test: (1293, 48, 300)
# num_classes: 21
# ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raise', 'leg extension', 'leg raises', 'pull Up', 'push-up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep Pushdown', 'tricep dips']

# %%
# ============================================================
# 4. Scaling + augmentation helpers
# ============================================================
def scale_sequence_data(X_train, X_val):
    n_train, t, f = X_train.shape
    n_val = X_val.shape[0]

    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(
        X_train.reshape(-1, f)
    ).reshape(n_train, t, f)

    X_val_scaled = scaler.transform(
        X_val.reshape(-1, f)
    ).reshape(n_val, t, f)

    return X_train_scaled.astype(np.float32), X_val_scaled.astype(np.float32), scaler


def scale_with_existing_scaler(X, scaler):
    n, t, f = X.shape

    return scaler.transform(
        X.reshape(-1, f)
    ).reshape(n, t, f).astype(np.float32)


def augment_sequence(seq):
    aug = seq.copy()

    aug += np.random.normal(0, 0.015, size=aug.shape)
    aug *= np.random.normal(1.0, 0.025)

    shift = np.random.randint(-4, 5)
    aug = np.roll(aug, shift=shift, axis=0)

    for i in range(1, len(aug)):
        if np.random.rand() < 0.06:
            aug[i] = aug[i - 1]

    if np.random.rand() < 0.15:
        mask_len = np.random.randint(1, 6)
        start = np.random.randint(0, max(1, len(aug) - mask_len))
        replacement = aug[start - 1] if start > 0 else aug[start]
        aug[start:start + mask_len] = replacement

    feature_mask = np.random.rand(aug.shape[1]) < 0.04
    aug[:, feature_mask] = 0

    return aug.astype(np.float32)


def make_augmented_training_data(X_train, y_train, copies=2):
    X_list = [X_train]
    y_list = [y_train]

    for _ in range(copies):
        X_aug = np.array([augment_sequence(seq) for seq in X_train], dtype=np.float32)
        X_list.append(X_aug)
        y_list.append(y_train)

    return np.concatenate(X_list), np.concatenate(y_list)

# %%
# ============================================================
# 5. CNN-only model
# ============================================================
class WorkoutClassifierCNN(nn.Module):
    def __init__(
        self,
        input_size,
        num_classes,
        channels=(96, 128, 192, 256),
        kernels=(3, 5, 3, 3),
        dropout=0.3
    ):
        super().__init__()

        c1, c2, c3, c4 = channels
        k1, k2, k3, k4 = kernels

        self.features = nn.Sequential(
            nn.Conv1d(input_size, c1, kernel_size=k1, padding=k1 // 2),
            nn.BatchNorm1d(c1),
            nn.ReLU(),
            nn.Dropout(dropout * 0.6),

            nn.Conv1d(c1, c2, kernel_size=k2, padding=k2 // 2),
            nn.BatchNorm1d(c2),
            nn.ReLU(),
            nn.Dropout(dropout * 0.7),

            nn.Conv1d(c2, c3, kernel_size=k3, padding=k3 // 2),
            nn.BatchNorm1d(c3),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Conv1d(c3, c4, kernel_size=k4, padding=k4 // 2),
            nn.BatchNorm1d(c4),
            nn.ReLU()
        )

        self.classifier = nn.Sequential(
            nn.Linear(c4 * 2, 256),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = x.transpose(1, 2)
        x = self.features(x)

        avg_pool = torch.mean(x, dim=2)
        max_pool = torch.max(x, dim=2).values

        x = torch.cat([avg_pool, max_pool], dim=1)

        return self.classifier(x)

# %%
# ============================================================
# 6. Training helpers
# ============================================================
def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())

    trainable = sum(
        p.numel()
        for p in model.parameters()
        if p.requires_grad
    )

    print(model)
    print(f"Total params: {total:,}")
    print(f"Trainable params: {trainable:,}")


def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for batch_X, batch_y in loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(batch_y).sum().item()
        total += batch_y.size(0)

    return total_loss / len(loader), correct / total


def evaluate(model, loader, criterion, device):
    model.eval()

    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch_X, batch_y in loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)

            total_loss += loss.item()

            _, predicted = outputs.max(1)
            correct += predicted.eq(batch_y).sum().item()
            total += batch_y.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(batch_y.cpu().numpy())

    return total_loss / len(loader), correct / total, all_preds, all_labels

# %%
# ============================================================
# 7. CNN Hyperparameter Search Space
# ============================================================

HYPERPARAM_GRID = [
    {
        "channels": (96, 128, 192, 256),
        "kernels": (3, 5, 3, 3),
        "dropout": 0.30,
        "lr": 1e-3,
        "weight_decay": 1e-5
    },
    {
        "channels": (64, 128, 192, 256),
        "kernels": (3, 5, 5, 3),
        "dropout": 0.30,
        "lr": 1e-3,
        "weight_decay": 1e-5
    },
    {
        "channels": (96, 160, 224, 288),
        "kernels": (3, 5, 3, 3),
        "dropout": 0.35,
        "lr": 5e-4,
        "weight_decay": 1e-5
    },
    {
        "channels": (128, 160, 224, 320),
        "kernels": (5, 5, 3, 3),
        "dropout": 0.40,
        "lr": 5e-4,
        "weight_decay": 1e-5
    }
]

# %%
# ============================================================
# 8. CNN Hyperparameter Search with GroupKFold
# ============================================================

best_all_true = None
best_all_pred = None
best_fold_accuracies = None
best_fold_macro_f1 = None
best_fold_weighted_f1 = None
best_history = None
best_fold = None

gkf = GroupKFold(n_splits=N_SPLITS)
groups = kept_verified_df["filepath"].values

search_results = []

best_config = None
best_cv_macro_f1 = -1
best_cv_accuracy = -1

for config_id, config in enumerate(HYPERPARAM_GRID, start=1):
    print("\n" + "=" * 70)
    print(f"Testing CNN config {config_id}/{len(HYPERPARAM_GRID)}")
    print(config)
    print("=" * 70)

    fold_accuracies = []
    fold_macro_f1 = []
    fold_weighted_f1 = []

    config_all_true = []
    config_all_pred = []
    config_best_history = None
    config_best_fold = None
    config_best_acc = 0

    for fold, (train_idx, val_idx) in enumerate(
        gkf.split(X_verified, y_verified, groups=groups),
        start=1
    ):
        print(f"\n---------- Config {config_id} | Fold {fold} ----------")

        X_train_raw = X_verified[train_idx]
        X_val_raw = X_verified[val_idx]

        y_train = y_verified[train_idx]
        y_val = y_verified[val_idx]

        X_train, X_val, scaler = scale_sequence_data(
            X_train_raw,
            X_val_raw
        )

        X_train_aug, y_train_aug = make_augmented_training_data(
            X_train,
            y_train,
            copies=2
        )

        train_loader = DataLoader(
            TensorDataset(
                torch.FloatTensor(X_train_aug),
                torch.LongTensor(y_train_aug)
            ),
            batch_size=BATCH_SIZE,
            shuffle=True,
            num_workers=2,
            pin_memory=True
        )

        val_loader = DataLoader(
            TensorDataset(
                torch.FloatTensor(X_val),
                torch.LongTensor(y_val)
            ),
            batch_size=BATCH_SIZE,
            shuffle=False
        )

        model = WorkoutClassifierCNN(
            input_size=FEATURE_SIZE,
            num_classes=num_classes,
            channels=config["channels"],
            kernels=config["kernels"],
            dropout=config["dropout"]
        ).to(DEVICE)

        if config_id == 1 and fold == 1:
            count_parameters(model)

        class_weights_arr = compute_class_weight(
            class_weight="balanced",
            classes=np.unique(y_train_aug),
            y=y_train_aug
        )

        criterion = nn.CrossEntropyLoss(
            weight=torch.FloatTensor(class_weights_arr).to(DEVICE)
        )

        optimizer = optim.Adam(
            model.parameters(),
            lr=config["lr"],
            weight_decay=config["weight_decay"]
        )

        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode="min",
            patience=5,
            factor=0.5
        )

        fold_best_acc = 0
        fold_best_state = None
        patience = 15
        patience_counter = 0

        history = {
            "train_loss": [],
            "val_loss": [],
            "train_acc": [],
            "val_acc": []
        }

        for epoch in range(1, EPOCHS + 1):
            train_loss, train_acc = train_one_epoch(
                model,
                train_loader,
                criterion,
                optimizer,
                DEVICE
            )

            val_loss, val_acc, val_preds, val_labels = evaluate(
                model,
                val_loader,
                criterion,
                DEVICE
            )

            scheduler.step(val_loss)

            history["train_loss"].append(train_loss)
            history["val_loss"].append(val_loss)
            history["train_acc"].append(train_acc)
            history["val_acc"].append(val_acc)

            if val_acc > fold_best_acc:
                fold_best_acc = val_acc
                fold_best_state = {
                    k: v.cpu().clone()
                    for k, v in model.state_dict().items()
                }
                patience_counter = 0
            else:
                patience_counter += 1

            if epoch == 1 or epoch % 5 == 0:
                print(
                    f"Epoch {epoch:03d}/{EPOCHS} | "
                    f"Train Acc: {train_acc:.4f} | "
                    f"Val Acc: {val_acc:.4f} | "
                    f"Val Loss: {val_loss:.4f}"
                )

            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch}")
                break

        model.load_state_dict(fold_best_state)
        model = model.to(DEVICE)

        val_loss, val_acc, val_preds, val_labels = evaluate(
            model,
            val_loader,
            criterion,
            DEVICE
        )

        macro = f1_score(
            val_labels,
            val_preds,
            average="macro"
        )

        weighted = f1_score(
            val_labels,
            val_preds,
            average="weighted"
        )

        fold_accuracies.append(val_acc)
        fold_macro_f1.append(macro)
        fold_weighted_f1.append(weighted)

        config_all_true.extend(val_labels)
        config_all_pred.extend(val_preds)

        if val_acc > config_best_acc:
            config_best_acc = val_acc
            config_best_history = history
            config_best_fold = fold

        print(f"Fold {fold} Accuracy: {val_acc:.4f}")
        print(f"Fold {fold} Macro F1: {macro:.4f}")
        print(f"Fold {fold} Weighted F1: {weighted:.4f}")

    mean_acc = np.mean(fold_accuracies)
    mean_macro = np.mean(fold_macro_f1)
    mean_weighted = np.mean(fold_weighted_f1)

    result = {
        "config_id": config_id,
        "channels": str(config["channels"]),
        "kernels": str(config["kernels"]),
        "dropout": config["dropout"],
        "lr": config["lr"],
        "weight_decay": config["weight_decay"],
        "mean_accuracy": mean_acc,
        "mean_macro_f1": mean_macro,
        "mean_weighted_f1": mean_weighted
    }

    search_results.append(result)

    print("\nConfig Results:")
    print(result)

    if mean_macro > best_cv_macro_f1:
        best_cv_macro_f1 = mean_macro
        best_cv_accuracy = mean_acc
        best_config = config

        best_all_true = config_all_true
        best_all_pred = config_all_pred
        best_fold_accuracies = fold_accuracies
        best_fold_macro_f1 = fold_macro_f1
        best_fold_weighted_f1 = fold_weighted_f1
        best_history = config_best_history
        best_fold = config_best_fold

print("\n================ BEST CNN HYPERPARAMETERS ================")
print("Best config:", best_config)
print("Best mean CV macro F1:", best_cv_macro_f1)
print("Best mean CV accuracy:", best_cv_accuracy)

search_results_df = pd.DataFrame(search_results)
display(search_results_df)

SEARCH_RESULTS_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_hyperparameter_search_results.csv"
)

search_results_df.to_csv(
    SEARCH_RESULTS_PATH,
    index=False
)

print("Saved hyperparameter search results to:", SEARCH_RESULTS_PATH)
# Out:
# ======================================================================
# Testing CNN config 1/4
# {'channels': (96, 128, 192, 256), 'kernels': (3, 5, 3, 3), 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 1 | Fold 1 ----------
# WorkoutClassifierCNN(
#   (features): Sequential(
#     (0): Conv1d(300, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.18, inplace=False)
#     (4): Conv1d(96, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.21, inplace=False)
#     (8): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3, inplace=False)
#     (12): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (13): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )
# Total params: 537,973
# Trainable params: 537,973
# Epoch 001/80 | Train Acc: 0.5549 | Val Acc: 0.7345 | Val Loss: 0.9285
# Epoch 005/80 | Train Acc: 0.8772 | Val Acc: 0.8256 | Val Loss: 0.8121
# Epoch 010/80 | Train Acc: 0.9300 | Val Acc: 0.8466 | Val Loss: 0.7813
# Epoch 015/80 | Train Acc: 0.9683 | Val Acc: 0.8563 | Val Loss: 1.0560
# Epoch 020/80 | Train Acc: 0.9828 | Val Acc: 0.8555 | Val Loss: 1.2298
# Epoch 025/80 | Train Acc: 0.9877 | Val Acc: 0.8668 | Val Loss: 1.2615
# Epoch 030/80 | Train Acc: 0.9912 | Val Acc: 0.8643 | Val Loss: 1.2583
# Epoch 035/80 | Train Acc: 0.9929 | Val Acc: 0.8676 | Val Loss: 1.3549
# Epoch 040/80 | Train Acc: 0.9925 | Val Acc: 0.8622 | Val Loss: 1.3819
# Epoch 045/80 | Train Acc: 0.9940 | Val Acc: 0.8672 | Val Loss: 1.3582
# Epoch 050/80 | Train Acc: 0.9938 | Val Acc: 0.8714 | Val Loss: 1.2896
# Early stopping at epoch 52
# Fold 1 Accuracy: 0.8739
# Fold 1 Macro F1: 0.8647
# Fold 1 Weighted F1: 0.8717
#
# ---------- Config 1 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.5703 | Val Acc: 0.7193 | Val Loss: 0.8840
# Epoch 005/80 | Train Acc: 0.8817 | Val Acc: 0.8282 | Val Loss: 0.6558
# Epoch 010/80 | Train Acc: 0.9356 | Val Acc: 0.8445 | Val Loss: 0.7005
# Epoch 015/80 | Train Acc: 0.9714 | Val Acc: 0.8714 | Val Loss: 0.6796
# Epoch 020/80 | Train Acc: 0.9822 | Val Acc: 0.8710 | Val Loss: 0.7710
# Epoch 025/80 | Train Acc: 0.9889 | Val Acc: 0.8782 | Val Loss: 0.8320
# Epoch 030/80 | Train Acc: 0.9923 | Val Acc: 0.8807 | Val Loss: 0.8719
# Epoch 035/80 | Train Acc: 0.9942 | Val Acc: 0.8769 | Val Loss: 0.9327
# Epoch 040/80 | Train Acc: 0.9943 | Val Acc: 0.8744 | Val Loss: 0.9556
# Epoch 045/80 | Train Acc: 0.9954 | Val Acc: 0.8769 | Val Loss: 0.9274
# Epoch 050/80 | Train Acc: 0.9953 | Val Acc: 0.8756 | Val Loss: 0.9525
# Early stopping at epoch 51
# Fold 2 Accuracy: 0.8824
# Fold 2 Macro F1: 0.8737
# Fold 2 Weighted F1: 0.8835
#
# ---------- Config 1 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.5693 | Val Acc: 0.7461 | Val Loss: 0.7340
# Epoch 005/80 | Train Acc: 0.8798 | Val Acc: 0.8335 | Val Loss: 0.5893
# Epoch 010/80 | Train Acc: 0.9336 | Val Acc: 0.8483 | Val Loss: 0.6673
# Epoch 015/80 | Train Acc: 0.9731 | Val Acc: 0.8693 | Val Loss: 0.8033
# Epoch 020/80 | Train Acc: 0.9845 | Val Acc: 0.8836 | Val Loss: 0.7548
# Epoch 025/80 | Train Acc: 0.9896 | Val Acc: 0.8823 | Val Loss: 0.7983
# Epoch 030/80 | Train Acc: 0.9924 | Val Acc: 0.8857 | Val Loss: 0.9043
# Epoch 035/80 | Train Acc: 0.9944 | Val Acc: 0.8789 | Val Loss: 0.9287
# Epoch 040/80 | Train Acc: 0.9947 | Val Acc: 0.8810 | Val Loss: 0.9398
# Epoch 045/80 | Train Acc: 0.9949 | Val Acc: 0.8810 | Val Loss: 0.9497
# Early stopping at epoch 45
# Fold 3 Accuracy: 0.8857
# Fold 3 Macro F1: 0.8851
# Fold 3 Weighted F1: 0.8866
#
# ---------- Config 1 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.5515 | Val Acc: 0.6965 | Val Loss: 0.9117
# Epoch 005/80 | Train Acc: 0.8812 | Val Acc: 0.8016 | Val Loss: 0.7914
# Epoch 010/80 | Train Acc: 0.9327 | Val Acc: 0.8272 | Val Loss: 0.8119
# Epoch 015/80 | Train Acc: 0.9535 | Val Acc: 0.8356 | Val Loss: 0.8207
# Epoch 020/80 | Train Acc: 0.9801 | Val Acc: 0.8483 | Val Loss: 1.0040
# Epoch 025/80 | Train Acc: 0.9888 | Val Acc: 0.8726 | Val Loss: 0.9437
# Epoch 030/80 | Train Acc: 0.9925 | Val Acc: 0.8739 | Val Loss: 1.0425
# Epoch 035/80 | Train Acc: 0.9946 | Val Acc: 0.8663 | Val Loss: 1.0927
# Epoch 040/80 | Train Acc: 0.9957 | Val Acc: 0.8722 | Val Loss: 1.0083
# Epoch 045/80 | Train Acc: 0.9955 | Val Acc: 0.8735 | Val Loss: 0.9836
# Early stopping at epoch 46
# Fold 4 Accuracy: 0.8777
# Fold 4 Macro F1: 0.8824
# Fold 4 Weighted F1: 0.8775
#
# ---------- Config 1 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.5724 | Val Acc: 0.7167 | Val Loss: 0.8277
# Epoch 005/80 | Train Acc: 0.8769 | Val Acc: 0.8256 | Val Loss: 0.7752
# Epoch 010/80 | Train Acc: 0.9324 | Val Acc: 0.8525 | Val Loss: 0.7205
# Epoch 015/80 | Train Acc: 0.9543 | Val Acc: 0.8609 | Val Loss: 0.7655
# Epoch 020/80 | Train Acc: 0.9802 | Val Acc: 0.8659 | Val Loss: 0.9959
# Epoch 025/80 | Train Acc: 0.9886 | Val Acc: 0.8726 | Val Loss: 1.0015
# Epoch 030/80 | Train Acc: 0.9905 | Val Acc: 0.8768 | Val Loss: 1.0911
# Epoch 035/80 | Train Acc: 0.9944 | Val Acc: 0.8781 | Val Loss: 1.1952
# Epoch 040/80 | Train Acc: 0.9955 | Val Acc: 0.8764 | Val Loss: 1.1618
# Early stopping at epoch 41
# Fold 5 Accuracy: 0.8907
# Fold 5 Macro F1: 0.8861
# Fold 5 Weighted F1: 0.8912
#
# Config Results:
# {'config_id': 1, 'channels': '(96, 128, 192, 256)', 'kernels': '(3, 5, 3, 3)', 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05, 'mean_accuracy': np.float64(0.8820717694391753), 'mean_macro_f1': np.float64(0.878396255870338), 'mean_weighted_f1': np.float64(0.8820738359249809)}
#
# ======================================================================
# Testing CNN config 2/4
# {'channels': (64, 128, 192, 256), 'kernels': (3, 5, 5, 3), 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 2 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.5404 | Val Acc: 0.7374 | Val Loss: 0.9224
# Epoch 005/80 | Train Acc: 0.8669 | Val Acc: 0.8324 | Val Loss: 0.7124
# Epoch 010/80 | Train Acc: 0.9233 | Val Acc: 0.8424 | Val Loss: 0.7960
# Epoch 015/80 | Train Acc: 0.9643 | Val Acc: 0.8744 | Val Loss: 0.8374
# Epoch 020/80 | Train Acc: 0.9792 | Val Acc: 0.8681 | Val Loss: 0.9643
# Epoch 025/80 | Train Acc: 0.9875 | Val Acc: 0.8840 | Val Loss: 0.9780
# Epoch 030/80 | Train Acc: 0.9904 | Val Acc: 0.8769 | Val Loss: 0.9799
# Epoch 035/80 | Train Acc: 0.9910 | Val Acc: 0.8824 | Val Loss: 1.0027
# Epoch 040/80 | Train Acc: 0.9917 | Val Acc: 0.8777 | Val Loss: 1.0349
# Early stopping at epoch 40
# Fold 1 Accuracy: 0.8840
# Fold 1 Macro F1: 0.8786
# Fold 1 Weighted F1: 0.8808
#
# ---------- Config 2 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.5404 | Val Acc: 0.7315 | Val Loss: 0.8835
# Epoch 005/80 | Train Acc: 0.8716 | Val Acc: 0.8025 | Val Loss: 0.7686
# Epoch 010/80 | Train Acc: 0.9227 | Val Acc: 0.8450 | Val Loss: 0.7501
# Epoch 015/80 | Train Acc: 0.9626 | Val Acc: 0.8647 | Val Loss: 0.8561
# Epoch 020/80 | Train Acc: 0.9789 | Val Acc: 0.8605 | Val Loss: 1.0636
# Epoch 025/80 | Train Acc: 0.9860 | Val Acc: 0.8794 | Val Loss: 1.0935
# Epoch 030/80 | Train Acc: 0.9889 | Val Acc: 0.8714 | Val Loss: 1.1206
# Epoch 035/80 | Train Acc: 0.9915 | Val Acc: 0.8723 | Val Loss: 1.1036
# Epoch 040/80 | Train Acc: 0.9905 | Val Acc: 0.8752 | Val Loss: 1.0580
# Early stopping at epoch 40
# Fold 2 Accuracy: 0.8794
# Fold 2 Macro F1: 0.8653
# Fold 2 Weighted F1: 0.8798
#
# ---------- Config 2 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.5106 | Val Acc: 0.6936 | Val Loss: 0.8728
# Epoch 005/80 | Train Acc: 0.8731 | Val Acc: 0.8398 | Val Loss: 0.5022
# Epoch 010/80 | Train Acc: 0.9287 | Val Acc: 0.8668 | Val Loss: 0.5320
# Epoch 015/80 | Train Acc: 0.9659 | Val Acc: 0.8785 | Val Loss: 0.5993
# Epoch 020/80 | Train Acc: 0.9799 | Val Acc: 0.8815 | Val Loss: 0.6655
# Epoch 025/80 | Train Acc: 0.9873 | Val Acc: 0.8798 | Val Loss: 0.7388
# Epoch 030/80 | Train Acc: 0.9901 | Val Acc: 0.8899 | Val Loss: 0.7362
# Epoch 035/80 | Train Acc: 0.9908 | Val Acc: 0.8894 | Val Loss: 0.7568
# Epoch 040/80 | Train Acc: 0.9925 | Val Acc: 0.8911 | Val Loss: 0.7106
# Epoch 045/80 | Train Acc: 0.9928 | Val Acc: 0.8890 | Val Loss: 0.7833
# Epoch 050/80 | Train Acc: 0.9930 | Val Acc: 0.8882 | Val Loss: 0.7856
# Epoch 055/80 | Train Acc: 0.9932 | Val Acc: 0.8890 | Val Loss: 0.7872
# Early stopping at epoch 59
# Fold 3 Accuracy: 0.8932
# Fold 3 Macro F1: 0.8812
# Fold 3 Weighted F1: 0.8930
#
# ---------- Config 2 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.5478 | Val Acc: 0.6986 | Val Loss: 0.8068
# Epoch 005/80 | Train Acc: 0.8762 | Val Acc: 0.8054 | Val Loss: 0.6726
# Epoch 010/80 | Train Acc: 0.9244 | Val Acc: 0.8138 | Val Loss: 1.0828
# Epoch 015/80 | Train Acc: 0.9646 | Val Acc: 0.8520 | Val Loss: 0.7508
# Epoch 020/80 | Train Acc: 0.9800 | Val Acc: 0.8621 | Val Loss: 0.9357
# Epoch 025/80 | Train Acc: 0.9850 | Val Acc: 0.8571 | Val Loss: 0.9787
# Epoch 030/80 | Train Acc: 0.9897 | Val Acc: 0.8617 | Val Loss: 1.0678
# Epoch 035/80 | Train Acc: 0.9915 | Val Acc: 0.8651 | Val Loss: 1.0864
# Epoch 040/80 | Train Acc: 0.9922 | Val Acc: 0.8625 | Val Loss: 1.0716
# Epoch 045/80 | Train Acc: 0.9925 | Val Acc: 0.8604 | Val Loss: 1.1119
# Epoch 050/80 | Train Acc: 0.9924 | Val Acc: 0.8672 | Val Loss: 1.0523
# Early stopping at epoch 52
# Fold 4 Accuracy: 0.8693
# Fold 4 Macro F1: 0.8733
# Fold 4 Weighted F1: 0.8689
#
# ---------- Config 2 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.5483 | Val Acc: 0.7545 | Val Loss: 0.7730
# Epoch 005/80 | Train Acc: 0.8655 | Val Acc: 0.8331 | Val Loss: 0.5778
# Epoch 010/80 | Train Acc: 0.9202 | Val Acc: 0.8777 | Val Loss: 0.5286
# Epoch 015/80 | Train Acc: 0.9475 | Val Acc: 0.8668 | Val Loss: 0.5913
# Epoch 020/80 | Train Acc: 0.9753 | Val Acc: 0.8810 | Val Loss: 0.8115
# Epoch 025/80 | Train Acc: 0.9861 | Val Acc: 0.8869 | Val Loss: 0.8493
# Epoch 030/80 | Train Acc: 0.9905 | Val Acc: 0.8941 | Val Loss: 0.9062
# Epoch 035/80 | Train Acc: 0.9920 | Val Acc: 0.8920 | Val Loss: 0.9312
# Early stopping at epoch 36
# Fold 5 Accuracy: 0.8991
# Fold 5 Macro F1: 0.8992
# Fold 5 Weighted F1: 0.9001
#
# Config Results:
# {'config_id': 2, 'channels': '(64, 128, 192, 256)', 'kernels': '(3, 5, 5, 3)', 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05, 'mean_accuracy': np.float64(0.88501358172525), 'mean_macro_f1': np.float64(0.8795219982792233), 'mean_weighted_f1': np.float64(0.8845200866691757)}
#
# ======================================================================
# Testing CNN config 3/4
# {'channels': (96, 160, 224, 288), 'kernels': (3, 5, 3, 3), 'dropout': 0.35, 'lr': 0.0005, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 3 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.5363 | Val Acc: 0.7227 | Val Loss: 0.8162
# Epoch 005/80 | Train Acc: 0.8913 | Val Acc: 0.8345 | Val Loss: 0.6949
# Epoch 010/80 | Train Acc: 0.9585 | Val Acc: 0.8845 | Val Loss: 0.7535
# Epoch 015/80 | Train Acc: 0.9715 | Val Acc: 0.8660 | Val Loss: 0.9287
# Epoch 020/80 | Train Acc: 0.9842 | Val Acc: 0.8718 | Val Loss: 0.9888
# Epoch 025/80 | Train Acc: 0.9891 | Val Acc: 0.8857 | Val Loss: 1.0683
# Epoch 030/80 | Train Acc: 0.9922 | Val Acc: 0.8874 | Val Loss: 1.0655
# Epoch 035/80 | Train Acc: 0.9928 | Val Acc: 0.8874 | Val Loss: 1.0050
# Epoch 040/80 | Train Acc: 0.9939 | Val Acc: 0.8903 | Val Loss: 1.0596
# Early stopping at epoch 44
# Fold 1 Accuracy: 0.8912
# Fold 1 Macro F1: 0.8836
# Fold 1 Weighted F1: 0.8890
#
# ---------- Config 3 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.5504 | Val Acc: 0.7244 | Val Loss: 0.8547
# Epoch 005/80 | Train Acc: 0.8873 | Val Acc: 0.8303 | Val Loss: 0.6334
# Epoch 010/80 | Train Acc: 0.9428 | Val Acc: 0.8466 | Val Loss: 0.8716
# Epoch 015/80 | Train Acc: 0.9746 | Val Acc: 0.8550 | Val Loss: 0.8681
# Epoch 020/80 | Train Acc: 0.9883 | Val Acc: 0.8702 | Val Loss: 1.0299
# Epoch 025/80 | Train Acc: 0.9918 | Val Acc: 0.8739 | Val Loss: 1.0201
# Epoch 030/80 | Train Acc: 0.9940 | Val Acc: 0.8761 | Val Loss: 1.0652
# Epoch 035/80 | Train Acc: 0.9940 | Val Acc: 0.8676 | Val Loss: 1.1346
# Epoch 040/80 | Train Acc: 0.9950 | Val Acc: 0.8718 | Val Loss: 1.0752
# Epoch 045/80 | Train Acc: 0.9952 | Val Acc: 0.8727 | Val Loss: 1.1059
# Epoch 050/80 | Train Acc: 0.9950 | Val Acc: 0.8794 | Val Loss: 1.1090
# Epoch 055/80 | Train Acc: 0.9954 | Val Acc: 0.8739 | Val Loss: 1.1161
# Early stopping at epoch 58
# Fold 2 Accuracy: 0.8803
# Fold 2 Macro F1: 0.8685
# Fold 2 Weighted F1: 0.8807
#
# ---------- Config 3 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.5556 | Val Acc: 0.7398 | Val Loss: 0.8001
# Epoch 005/80 | Train Acc: 0.8971 | Val Acc: 0.8386 | Val Loss: 0.5805
# Epoch 010/80 | Train Acc: 0.9433 | Val Acc: 0.8651 | Val Loss: 0.6235
# Epoch 015/80 | Train Acc: 0.9755 | Val Acc: 0.8743 | Val Loss: 0.7651
# Epoch 020/80 | Train Acc: 0.9883 | Val Acc: 0.8739 | Val Loss: 0.9739
# Epoch 025/80 | Train Acc: 0.9933 | Val Acc: 0.8764 | Val Loss: 1.0365
# Epoch 030/80 | Train Acc: 0.9931 | Val Acc: 0.8794 | Val Loss: 1.0015
# Epoch 035/80 | Train Acc: 0.9935 | Val Acc: 0.8815 | Val Loss: 0.9623
# Epoch 040/80 | Train Acc: 0.9959 | Val Acc: 0.8823 | Val Loss: 1.0171
# Early stopping at epoch 43
# Fold 3 Accuracy: 0.8882
# Fold 3 Macro F1: 0.8803
# Fold 3 Weighted F1: 0.8881
#
# ---------- Config 3 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.5383 | Val Acc: 0.7356 | Val Loss: 0.8526
# Epoch 005/80 | Train Acc: 0.8904 | Val Acc: 0.8184 | Val Loss: 0.7382
# Epoch 010/80 | Train Acc: 0.9563 | Val Acc: 0.8487 | Val Loss: 0.7865
# Epoch 015/80 | Train Acc: 0.9722 | Val Acc: 0.8453 | Val Loss: 0.9399
# Epoch 020/80 | Train Acc: 0.9863 | Val Acc: 0.8546 | Val Loss: 1.1583
# Epoch 025/80 | Train Acc: 0.9894 | Val Acc: 0.8579 | Val Loss: 1.1955
# Epoch 030/80 | Train Acc: 0.9923 | Val Acc: 0.8529 | Val Loss: 1.2735
# Epoch 035/80 | Train Acc: 0.9937 | Val Acc: 0.8562 | Val Loss: 1.2723
# Epoch 040/80 | Train Acc: 0.9946 | Val Acc: 0.8617 | Val Loss: 1.2310
# Early stopping at epoch 43
# Fold 4 Accuracy: 0.8684
# Fold 4 Macro F1: 0.8695
# Fold 4 Weighted F1: 0.8679
#
# ---------- Config 3 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.5303 | Val Acc: 0.7381 | Val Loss: 0.7952
# Epoch 005/80 | Train Acc: 0.8900 | Val Acc: 0.8201 | Val Loss: 0.6637
# Epoch 010/80 | Train Acc: 0.9388 | Val Acc: 0.8478 | Val Loss: 0.8148
# Epoch 015/80 | Train Acc: 0.9750 | Val Acc: 0.8567 | Val Loss: 0.9626
# Epoch 020/80 | Train Acc: 0.9873 | Val Acc: 0.8743 | Val Loss: 1.1135
# Epoch 025/80 | Train Acc: 0.9921 | Val Acc: 0.8810 | Val Loss: 1.0776
# Epoch 030/80 | Train Acc: 0.9930 | Val Acc: 0.8836 | Val Loss: 1.0348
# Epoch 035/80 | Train Acc: 0.9936 | Val Acc: 0.8722 | Val Loss: 1.1434
# Epoch 040/80 | Train Acc: 0.9946 | Val Acc: 0.8794 | Val Loss: 1.1236
# Epoch 045/80 | Train Acc: 0.9955 | Val Acc: 0.8747 | Val Loss: 1.1678
# Epoch 050/80 | Train Acc: 0.9949 | Val Acc: 0.8810 | Val Loss: 1.1721
# Early stopping at epoch 54
# Fold 5 Accuracy: 0.8852
# Fold 5 Macro F1: 0.8833
# Fold 5 Weighted F1: 0.8857
#
# Config Results:
# {'config_id': 3, 'channels': '(96, 160, 224, 288)', 'kernels': '(3, 5, 3, 3)', 'dropout': 0.35, 'lr': 0.0005, 'weight_decay': 1e-05, 'mean_accuracy': np.float64(0.8826589803638983), 'mean_macro_f1': np.float64(0.8770387703848993), 'mean_weighted_f1': np.float64(0.8822915096081042)}
#
# ======================================================================
# Testing CNN config 4/4
# {'channels': (128, 160, 224, 320), 'kernels': (5, 5, 3, 3), 'dropout': 0.4, 'lr': 0.0005, 'weight_decay': 1e-05}
# ======================================================================
#
# ---------- Config 4 | Fold 1 ----------
# Epoch 001/80 | Train Acc: 0.4774 | Val Acc: 0.7504 | Val Loss: 0.9169
# Epoch 005/80 | Train Acc: 0.8750 | Val Acc: 0.8294 | Val Loss: 0.6747
# Epoch 010/80 | Train Acc: 0.9346 | Val Acc: 0.8504 | Val Loss: 0.7302
# Epoch 015/80 | Train Acc: 0.9712 | Val Acc: 0.8626 | Val Loss: 0.9647
# Epoch 020/80 | Train Acc: 0.9836 | Val Acc: 0.8681 | Val Loss: 0.9814
# Epoch 025/80 | Train Acc: 0.9907 | Val Acc: 0.8626 | Val Loss: 1.1833
# Epoch 030/80 | Train Acc: 0.9925 | Val Acc: 0.8706 | Val Loss: 1.1353
# Epoch 035/80 | Train Acc: 0.9933 | Val Acc: 0.8706 | Val Loss: 1.1704
# Epoch 040/80 | Train Acc: 0.9948 | Val Acc: 0.8697 | Val Loss: 1.2342
# Early stopping at epoch 44
# Fold 1 Accuracy: 0.8744
# Fold 1 Macro F1: 0.8656
# Fold 1 Weighted F1: 0.8714
#
# ---------- Config 4 | Fold 2 ----------
# Epoch 001/80 | Train Acc: 0.4897 | Val Acc: 0.7332 | Val Loss: 0.9370
# Epoch 005/80 | Train Acc: 0.8836 | Val Acc: 0.8353 | Val Loss: 0.5892
# Epoch 010/80 | Train Acc: 0.9372 | Val Acc: 0.8542 | Val Loss: 0.6804
# Epoch 015/80 | Train Acc: 0.9713 | Val Acc: 0.8697 | Val Loss: 0.8141
# Epoch 020/80 | Train Acc: 0.9859 | Val Acc: 0.8794 | Val Loss: 0.8744
# Epoch 025/80 | Train Acc: 0.9905 | Val Acc: 0.8866 | Val Loss: 0.9199
# Epoch 030/80 | Train Acc: 0.9921 | Val Acc: 0.8891 | Val Loss: 0.9130
# Epoch 035/80 | Train Acc: 0.9938 | Val Acc: 0.8887 | Val Loss: 0.9597
# Epoch 040/80 | Train Acc: 0.9948 | Val Acc: 0.8891 | Val Loss: 0.9351
# Epoch 045/80 | Train Acc: 0.9956 | Val Acc: 0.8891 | Val Loss: 0.9539
# Early stopping at epoch 47
# Fold 2 Accuracy: 0.8912
# Fold 2 Macro F1: 0.8808
# Fold 2 Weighted F1: 0.8919
#
# ---------- Config 4 | Fold 3 ----------
# Epoch 001/80 | Train Acc: 0.4815 | Val Acc: 0.7280 | Val Loss: 0.8528
# Epoch 005/80 | Train Acc: 0.8787 | Val Acc: 0.8457 | Val Loss: 0.5696
# Epoch 010/80 | Train Acc: 0.9364 | Val Acc: 0.8676 | Val Loss: 0.5652
# Epoch 015/80 | Train Acc: 0.9738 | Val Acc: 0.8714 | Val Loss: 0.6823
# Epoch 020/80 | Train Acc: 0.9864 | Val Acc: 0.8789 | Val Loss: 0.8452
# Epoch 025/80 | Train Acc: 0.9909 | Val Acc: 0.8873 | Val Loss: 0.7933
# Epoch 030/80 | Train Acc: 0.9914 | Val Acc: 0.8861 | Val Loss: 0.8380
# Epoch 035/80 | Train Acc: 0.9940 | Val Acc: 0.8882 | Val Loss: 0.8041
# Epoch 040/80 | Train Acc: 0.9945 | Val Acc: 0.8852 | Val Loss: 0.9001
# Epoch 045/80 | Train Acc: 0.9951 | Val Acc: 0.8882 | Val Loss: 0.8819
# Epoch 050/80 | Train Acc: 0.9948 | Val Acc: 0.8865 | Val Loss: 0.8784
# Early stopping at epoch 54
# Fold 3 Accuracy: 0.8920
# Fold 3 Macro F1: 0.8904
# Fold 3 Weighted F1: 0.8920
#
# ---------- Config 4 | Fold 4 ----------
# Epoch 001/80 | Train Acc: 0.5056 | Val Acc: 0.6995 | Val Loss: 0.8980
# Epoch 005/80 | Train Acc: 0.8816 | Val Acc: 0.8214 | Val Loss: 0.7314
# Epoch 010/80 | Train Acc: 0.9545 | Val Acc: 0.8352 | Val Loss: 0.8341
# Epoch 015/80 | Train Acc: 0.9717 | Val Acc: 0.8390 | Val Loss: 0.9079
# Epoch 020/80 | Train Acc: 0.9843 | Val Acc: 0.8499 | Val Loss: 1.0917
# Epoch 025/80 | Train Acc: 0.9891 | Val Acc: 0.8525 | Val Loss: 1.1040
# Epoch 030/80 | Train Acc: 0.9913 | Val Acc: 0.8508 | Val Loss: 1.1319
# Epoch 035/80 | Train Acc: 0.9929 | Val Acc: 0.8567 | Val Loss: 1.1900
# Epoch 040/80 | Train Acc: 0.9941 | Val Acc: 0.8550 | Val Loss: 1.1675
# Epoch 045/80 | Train Acc: 0.9942 | Val Acc: 0.8550 | Val Loss: 1.1977
# Epoch 050/80 | Train Acc: 0.9942 | Val Acc: 0.8567 | Val Loss: 1.1667
# Epoch 055/80 | Train Acc: 0.9943 | Val Acc: 0.8583 | Val Loss: 1.1754
# Epoch 060/80 | Train Acc: 0.9943 | Val Acc: 0.8579 | Val Loss: 1.1809
# Early stopping at epoch 61
# Fold 4 Accuracy: 0.8617
# Fold 4 Macro F1: 0.8645
# Fold 4 Weighted F1: 0.8599
#
# ---------- Config 4 | Fold 5 ----------
# Epoch 001/80 | Train Acc: 0.4761 | Val Acc: 0.7385 | Val Loss: 0.8544
# Epoch 005/80 | Train Acc: 0.8728 | Val Acc: 0.8361 | Val Loss: 0.6411
# Epoch 010/80 | Train Acc: 0.9338 | Val Acc: 0.8415 | Val Loss: 0.9237
# Epoch 015/80 | Train Acc: 0.9552 | Val Acc: 0.8655 | Val Loss: 0.7711
# Epoch 020/80 | Train Acc: 0.9812 | Val Acc: 0.8840 | Val Loss: 0.9331
# Epoch 025/80 | Train Acc: 0.9887 | Val Acc: 0.8773 | Val Loss: 0.9693
# Epoch 030/80 | Train Acc: 0.9923 | Val Acc: 0.8836 | Val Loss: 1.0499
# Epoch 035/80 | Train Acc: 0.9937 | Val Acc: 0.8844 | Val Loss: 1.0263
# Early stopping at epoch 36
# Fold 5 Accuracy: 0.8911
# Fold 5 Macro F1: 0.8910
# Fold 5 Weighted F1: 0.8919
#
# Config Results:
# {'config_id': 4, 'channels': '(128, 160, 224, 320)', 'kernels': '(5, 5, 3, 3)', 'dropout': 0.4, 'lr': 0.0005, 'weight_decay': 1e-05, 'mean_accuracy': np.float64(0.8820709923313588), 'mean_macro_f1': np.float64(0.8784626634053667), 'mean_weighted_f1': np.float64(0.8814108556383615)}
#
# ================ BEST CNN HYPERPARAMETERS ================
# Best config: {'channels': (64, 128, 192, 256), 'kernels': (3, 5, 5, 3), 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 1e-05}
# Best mean CV macro F1: 0.8795219982792233
# Best mean CV accuracy: 0.88501358172525
#    config_id              channels       kernels  dropout      lr  \
# 0          1   (96, 128, 192, 256)  (3, 5, 3, 3)     0.30  0.0010
# 1          2   (64, 128, 192, 256)  (3, 5, 5, 3)     0.30  0.0010
# 2          3   (96, 160, 224, 288)  (3, 5, 3, 3)     0.35  0.0005
# 3          4  (128, 160, 224, 320)  (5, 5, 3, 3)     0.40  0.0005
#
#    weight_decay  mean_accuracy  mean_macro_f1  mean_weighted_f1
# 0       0.00001       0.882072       0.878396          0.882074
# 1       0.00001       0.885014       0.879522          0.884520
# 2       0.00001       0.882659       0.877039          0.882292
# 3       0.00001       0.882071       0.878463          0.881411
# Saved hyperparameter search results to: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_coreml/torch_cnn_hyperparameter_search_results.csv

# %%
# ============================================================
# 9. Save best-config CV results + graphs
# ============================================================

results_df = pd.DataFrame({
    "fold": list(range(1, len(best_fold_accuracies) + 1)),
    "accuracy": best_fold_accuracies,
    "macro_f1": best_fold_macro_f1,
    "weighted_f1": best_fold_weighted_f1
})

CV_RESULTS_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_best_config_cv_results.csv"
)

results_df.to_csv(CV_RESULTS_PATH, index=False)
display(results_df)

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_acc"], label="train_acc")
plt.plot(best_history["val_acc"], label="val_acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title(f"PyTorch CNN Accuracy - Best Config, Fold {best_fold}")
plt.legend()

ACC_PLOT_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_best_config_accuracy.png"
)

plt.savefig(
    ACC_PLOT_PATH,
    dpi=200,
    bbox_inches="tight"
)

plt.show()

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_loss"], label="train_loss")
plt.plot(best_history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"PyTorch CNN Loss - Best Config, Fold {best_fold}")
plt.legend()

LOSS_PLOT_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_best_config_loss.png"
)

plt.savefig(
    LOSS_PLOT_PATH,
    dpi=200,
    bbox_inches="tight"
)

plt.show()

print("Saved:", CV_RESULTS_PATH)
print("Saved:", ACC_PLOT_PATH)
print("Saved:", LOSS_PLOT_PATH)
# Out:
#    fold  accuracy  macro_f1  weighted_f1
# 0     1  0.884034  0.878605     0.880829
# 1     2  0.879412  0.865275     0.879753
# 2     3  0.893232  0.881226     0.893019
# 3     4  0.869273  0.873311     0.868900
# 4     5  0.899117  0.899193     0.900099
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_coreml/torch_cnn_best_config_cv_results.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_coreml/torch_cnn_best_config_accuracy.png
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_coreml/torch_cnn_best_config_loss.png

# %%
# ============================================================
# 10. CV classification report + confusion matrix for best config
# ============================================================

overall_report = classification_report(
    best_all_true,
    best_all_pred,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

report_df = pd.DataFrame(overall_report).transpose()

REPORT_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_best_config_cv_classification_report.csv"
)

report_df.to_csv(REPORT_PATH)
display(report_df)

cm = confusion_matrix(
    best_all_true,
    best_all_pred
)

plt.figure(figsize=(12, 10))
plt.imshow(cm)
plt.title("PyTorch CNN Best Config CV Confusion Matrix")
plt.colorbar()
plt.xticks(range(len(label_names)), label_names, rotation=90)
plt.yticks(range(len(label_names)), label_names)
plt.tight_layout()

CM_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_best_config_cv_confusion_matrix.png"
)

plt.savefig(
    CM_PATH,
    dpi=200,
    bbox_inches="tight"
)

plt.show()

np.save(
    os.path.join(
        OUTPUT_RESULT_DIR,
        "torch_cnn_best_config_cv_confusion_matrix.npy"
    ),
    cm
)

print("Saved:", REPORT_PATH)
print("Saved:", CM_PATH)
# Out:
#                      precision    recall  f1-score       support
# barbell biceps curl   0.793627  0.727399  0.759071    719.000000
# bench press           0.685115  0.697087  0.691049    515.000000
# chest fly machine     0.915385  0.945946  0.930414    629.000000
# deadlift              0.827160  0.879925  0.852727    533.000000
# decline bench press   0.877871  0.907228  0.892308    927.000000
# hammer curl           0.797500  0.852941  0.824289    748.000000
# hip thrust            0.928854  0.886792  0.907336    530.000000
# incline bench press   0.886128  0.904863  0.895397    473.000000
# lat pulldown          0.912921  0.868984  0.890411    374.000000
# lateral raise         0.878587  0.906606  0.892377    439.000000
# leg extension         0.939394  0.908795  0.923841    614.000000
# leg raises            0.944528  0.973725  0.958904    647.000000
# pull Up               0.952137  0.891200  0.920661    625.000000
# push-up               0.941512  0.944206  0.942857    699.000000
# romanian deadlift     0.853119  0.821705  0.837117    516.000000
# russian twist         0.964912  0.950324  0.957563    463.000000
# shoulder press        0.864865  0.941176  0.901408    374.000000
# squat                 0.950882  0.955696  0.953283    790.000000
# t bar row             0.881773  0.916382  0.898745    586.000000
# tricep Pushdown       0.882759  0.807571  0.843493    317.000000
# tricep dips           0.920821  0.828496  0.872222    379.000000
# accuracy              0.885013  0.885013  0.885013      0.885013
# macro avg             0.885707  0.881764  0.883118  11897.000000
# weighted avg          0.885706  0.885013  0.884810  11897.000000
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_coreml/torch_cnn_best_config_cv_classification_report.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_coreml/torch_cnn_best_config_cv_confusion_matrix.png

# %%
# ============================================================
# 11. Retrain final CNN on ALL verified data
# ============================================================

final_scaler = StandardScaler()

n, t, f = X_verified.shape

X_verified_scaled = final_scaler.fit_transform(
    X_verified.reshape(-1, f)
).reshape(n, t, f).astype(np.float32)

X_verified_aug, y_verified_aug = make_augmented_training_data(
    X_verified_scaled,
    y_verified,
    copies=2
)

train_loader = DataLoader(
    TensorDataset(
        torch.FloatTensor(X_verified_aug),
        torch.LongTensor(y_verified_aug)
    ),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

final_model = WorkoutClassifierCNN(
    input_size=FEATURE_SIZE,
    num_classes=num_classes,
    channels=best_config["channels"],
    kernels=best_config["kernels"],
    dropout=best_config["dropout"]
).to(DEVICE)

class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_verified_aug),
    y=y_verified_aug
)

criterion = nn.CrossEntropyLoss(
    weight=torch.FloatTensor(class_weights_arr).to(DEVICE)
)

optimizer = optim.Adam(
    final_model.parameters(),
    lr=best_config["lr"],
    weight_decay=best_config["weight_decay"]
)

FINAL_EPOCHS = 40

final_history = {
    "train_loss": [],
    "train_acc": []
}

for epoch in range(1, FINAL_EPOCHS + 1):
    train_loss, train_acc = train_one_epoch(
        final_model,
        train_loader,
        criterion,
        optimizer,
        DEVICE
    )

    final_history["train_loss"].append(train_loss)
    final_history["train_acc"].append(train_acc)

    if epoch == 1 or epoch % 5 == 0:
        print(
            f"Final Epoch {epoch:03d}/{FINAL_EPOCHS} | "
            f"Loss: {train_loss:.4f} | "
            f"Acc: {train_acc:.4f}"
        )

final_model.eval()
# Out:
# Final Epoch 001/40 | Loss: 1.2292 | Acc: 0.5846
# Final Epoch 005/40 | Loss: 0.3630 | Acc: 0.8822
# Final Epoch 010/40 | Loss: 0.2224 | Acc: 0.9298
# Final Epoch 015/40 | Loss: 0.1623 | Acc: 0.9494
# Final Epoch 020/40 | Loss: 0.1295 | Acc: 0.9621
# Final Epoch 025/40 | Loss: 0.1085 | Acc: 0.9693
# Final Epoch 030/40 | Loss: 0.1023 | Acc: 0.9720
# Final Epoch 035/40 | Loss: 0.0959 | Acc: 0.9730
# Final Epoch 040/40 | Loss: 0.0797 | Acc: 0.9783
# WorkoutClassifierCNN(
#   (features): Sequential(
#     (0): Conv1d(300, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.18, inplace=False)
#     (4): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.21, inplace=False)
#     (8): Conv1d(128, 192, kernel_size=(5,), stride=(1,), padding=(2,))
#     (9): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3, inplace=False)
#     (12): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (13): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )

# %%
# ============================================================
# 12. Evaluate final model on official test split
# ============================================================

X_test_scaled = scale_with_existing_scaler(
    X_test,
    final_scaler
)

test_loader = DataLoader(
    TensorDataset(
        torch.FloatTensor(X_test_scaled),
        torch.LongTensor(y_test)
    ),
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loss, test_acc, test_preds, test_labels = evaluate(
    final_model,
    test_loader,
    criterion,
    DEVICE
)

test_macro = f1_score(
    test_labels,
    test_preds,
    average="macro"
)

test_weighted = f1_score(
    test_labels,
    test_preds,
    average="weighted"
)

print("Official Test Accuracy:", test_acc)
print("Official Test Macro F1:", test_macro)
print("Official Test Weighted F1:", test_weighted)

print(classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0
))
# Out:
# Official Test Accuracy: 0.5699922660479505
# Official Test Macro F1: 0.5501146886971983
# Official Test Weighted F1: 0.56003738727482
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.32      0.86      0.46        49
#         bench press       0.23      0.78      0.36        36
#   chest fly machine       0.62      0.71      0.66        89
#            deadlift       0.72      0.78      0.74       156
# decline bench press       0.42      0.49      0.45        83
#         hammer curl       0.00      0.00      0.00        49
#          hip thrust       0.59      0.53      0.56        70
# incline bench press       0.00      0.00      0.00        77
#        lat pulldown       1.00      0.32      0.49        34
#       lateral raise       0.61      0.54      0.57        26
#       leg extension       0.47      0.97      0.63        36
#          leg raises       0.90      0.67      0.77        70
#             pull Up       0.65      0.65      0.65        62
#             push-up       0.98      0.57      0.72        82
#   romanian deadlift       0.36      0.24      0.29        50
#       russian twist       0.89      0.89      0.89        28
#      shoulder press       0.97      0.57      0.72        69
#               squat       0.26      0.27      0.27        55
#           t bar row       0.62      0.50      0.55        72
#     tricep Pushdown       0.87      1.00      0.93        27
#         tricep dips       0.89      0.78      0.83        73
#
#            accuracy                           0.57      1293
#           macro avg       0.59      0.58      0.55      1293
#        weighted avg       0.60      0.57      0.56      1293

# %%
# ============================================================
# 13. Save official test report + confusion matrix
# ============================================================

test_report = classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

test_report_df = pd.DataFrame(test_report).transpose()

TEST_REPORT_PATH = os.path.join(
    OUTPUT_RESULT_DIR,
    "torch_cnn_official_test_report.csv"
)

test_report_df.to_csv(TEST_REPORT_PATH)
display(test_report_df)

test_cm = confusion_matrix(
    test_labels,
    test_preds
)

plt.figure(figsize=(12, 10))
plt.imshow(test_cm)
plt.title("PyTorch CNN Official Test Confusion Matrix")
plt.colorbar()
plt.xticks(range(len(label_names)), label_names, rotation=90)
plt.yticks(range(len(label_names)), label_names)
plt.tight_layout()

TEST_CM_PATH = os.path.join(
    OUTPUT_GRAPH_DIR,
    "torch_cnn_official_test_confusion_matrix.png"
)

plt.savefig(
    TEST_CM_PATH,
    dpi=200,
    bbox_inches="tight"
)

plt.show()

np.save(
    os.path.join(
        OUTPUT_RESULT_DIR,
        "torch_cnn_official_test_confusion_matrix.npy"
    ),
    test_cm
)

print("Saved:", TEST_REPORT_PATH)
print("Saved:", TEST_CM_PATH)
# Out:
#                      precision    recall  f1-score      support
# barbell biceps curl   0.318182  0.857143  0.464088    49.000000
# bench press           0.233333  0.777778  0.358974    36.000000
# chest fly machine     0.623762  0.707865  0.663158    89.000000
# deadlift              0.715976  0.775641  0.744615   156.000000
# decline bench press   0.418367  0.493976  0.453039    83.000000
# hammer curl           0.000000  0.000000  0.000000    49.000000
# hip thrust            0.587302  0.528571  0.556391    70.000000
# incline bench press   0.000000  0.000000  0.000000    77.000000
# lat pulldown          1.000000  0.323529  0.488889    34.000000
# lateral raise         0.608696  0.538462  0.571429    26.000000
# leg extension         0.466667  0.972222  0.630631    36.000000
# leg raises            0.903846  0.671429  0.770492    70.000000
# pull Up               0.645161  0.645161  0.645161    62.000000
# push-up               0.979167  0.573171  0.723077    82.000000
# romanian deadlift     0.363636  0.240000  0.289157    50.000000
# russian twist         0.892857  0.892857  0.892857    28.000000
# shoulder press        0.975000  0.565217  0.715596    69.000000
# squat                 0.263158  0.272727  0.267857    55.000000
# t bar row             0.620690  0.500000  0.553846    72.000000
# tricep Pushdown       0.870968  1.000000  0.931034    27.000000
# tricep dips           0.890625  0.780822  0.832117    73.000000
# accuracy              0.569992  0.569992  0.569992     0.569992
# macro avg             0.589400  0.576980  0.550115  1293.000000
# weighted avg          0.599669  0.569992  0.560037  1293.000000
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/data/torch_cnn_coreml/torch_cnn_official_test_report.csv
# Saved: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/graphs/torch_cnn_coreml/torch_cnn_official_test_confusion_matrix.png

# %%
# ============================================================
# 14. Save checkpoint + scaler + labels
# ============================================================

final_model_cpu = final_model.cpu()

CHECKPOINT_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "best_workout_cnn_model.pth"
)

checkpoint = {
    "model_state_dict": final_model_cpu.state_dict(),
    "hyperparams": {
        "input_size": FEATURE_SIZE,
        "num_classes": num_classes,
        "channels": best_config["channels"],
        "kernels": best_config["kernels"],
        "dropout": best_config["dropout"],
        "sequence_length": SEQUENCE_LENGTH,
        "lr": best_config["lr"],
        "weight_decay": best_config["weight_decay"]
    },
    "best_config": best_config,
    "label_names": label_names,
    "test_accuracy": test_acc,
    "test_macro_f1": test_macro,
    "test_weighted_f1": test_weighted
}

torch.save(
    checkpoint,
    CHECKPOINT_PATH
)

SCALER_JSON_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "mediapipe_scaler.json"
)

with open(SCALER_JSON_PATH, "w") as f:
    json.dump({
        "mean": final_scaler.mean_.tolist(),
        "scale": final_scaler.scale_.tolist()
    }, f)

LABEL_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "label_names.json"
)

with open(LABEL_PATH, "w") as f:
    json.dump(label_names, f)

print("Saved checkpoint:", CHECKPOINT_PATH)
print("Saved scaler:", SCALER_JSON_PATH)
print("Saved labels:", LABEL_PATH)
# Out:
# Saved checkpoint: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_coreml/best_workout_cnn_model.pth
# Saved scaler: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_coreml/mediapipe_scaler.json
# Saved labels: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_coreml/label_names.json

# %%
# ============================================================
# 15. Convert final CNN model to CoreML
# ============================================================

export_model = WorkoutClassifierCNN(
    input_size=FEATURE_SIZE,
    num_classes=checkpoint["hyperparams"]["num_classes"],
    channels=checkpoint["hyperparams"]["channels"],
    kernels=checkpoint["hyperparams"]["kernels"],
    dropout=checkpoint["hyperparams"]["dropout"]
)

export_model.load_state_dict(
    checkpoint["model_state_dict"]
)

export_model.eval()

example_input = torch.rand(
    1,
    SEQUENCE_LENGTH,
    FEATURE_SIZE
)

with torch.no_grad():
    example_output = export_model(example_input)

print("Example input:", example_input.shape)
print("Example output:", example_output.shape)

traced_model = torch.jit.trace(
    export_model,
    example_input
)

coreml_model = ct.convert(
    traced_model,
    inputs=[
        ct.TensorType(
            name="input",
            shape=example_input.shape
        )
    ],
    outputs=[
        ct.TensorType(
            name="logits"
        )
    ],
    convert_to="mlprogram",
    minimum_deployment_target=ct.target.iOS15
)

COREML_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "WorkoutClassifierCNN.mlpackage"
)

coreml_model.save(COREML_PATH)

print("Saved CoreML model:", COREML_PATH)
# Out:
# Example input: torch.Size([1, 48, 300])
# Example output: torch.Size([1, 21])
# Converting PyTorch Frontend ==> MIL Ops:  98%|█████████▊| 63/64 [00:00<00:00, 1957.23 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 392.98 passes/s]
# Running MIL default pipeline: 100%|██████████| 95/95 [00:00<00:00, 287.82 passes/s]
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 717.83 passes/s]
# Saved CoreML model: /content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/models/torch_cnn_coreml/WorkoutClassifierCNN.mlpackage
