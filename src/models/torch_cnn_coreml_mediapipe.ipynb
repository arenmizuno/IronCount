# %% [markdown]
# # MediaPipe + CNN Classification Model
# ## ADSP 32023 - Advanced Computer Vision Using Deep Learning
# ## Spring 2026

# %%
# ============================================================
# 0. Install packages
# ============================================================
# !pip install -q torch torchvision torchaudio coremltools scikit-learn matplotlib pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.9 MB/s eta 0:00:00

# %%
# ============================================================
# 1. Imports
# ============================================================
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight
from google.colab import drive

import coremltools as ct

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# WARNING:coremltools:scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# WARNING:coremltools:XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING:coremltools:TensorFlow version 2.20.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# WARNING:coremltools:Torch version 2.10.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# Device: cuda

# %%
# ============================================================
# 2. Paths + config
# ============================================================
drive.mount("/content/drive")
PROJECT_DIR = "/content/drive/MyDrive/UChicago/Masters/Spring/ADSP 32023/Computer Vision Final Project/"

SAVE_DIR = os.path.join(PROJECT_DIR, "data", "preprocessed")
MODEL_DIR = os.path.join(PROJECT_DIR, "models")
GRAPH_DIR = os.path.join(PROJECT_DIR, "graphs")
RESULT_DIR = os.path.join(PROJECT_DIR, "data")
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(RESULT_DIR, exist_ok=True)

EXPERIMENT_NAME = "torch_cnn_coreml"
OUTPUT_MODEL_DIR = os.path.join(MODEL_DIR, EXPERIMENT_NAME)
OUTPUT_GRAPH_DIR = os.path.join(GRAPH_DIR, EXPERIMENT_NAME)
OUTPUT_RESULT_DIR = os.path.join(RESULT_DIR, EXPERIMENT_NAME)
os.makedirs(OUTPUT_MODEL_DIR, exist_ok=True)
os.makedirs(OUTPUT_GRAPH_DIR, exist_ok=True)
os.makedirs(OUTPUT_RESULT_DIR, exist_ok=True)

BATCH_SIZE = 32
EPOCHS = 80
N_SPLITS = 5

DROPOUT = 0.30
LR = 1e-3
WEIGHT_DECAY = 1e-5
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# 3. Load new extracted MediaPipe data
# ============================================================
X_verified = np.load(os.path.join(SAVE_DIR, "X_verified_mediapipe.npy"))
y_verified = np.load(os.path.join(SAVE_DIR, "y_verified.npy"))

X_test = np.load(os.path.join(SAVE_DIR, "X_test_mediapipe.npy"))
y_test = np.load(os.path.join(SAVE_DIR, "y_test.npy"))

kept_verified_df = pd.read_csv(os.path.join(SAVE_DIR, "kept_verified_mediapipe_dataset.csv"))

with open(os.path.join(SAVE_DIR, "label_names.json"), "r") as f:
    label_names = json.load(f)

num_classes = len(label_names)
SEQUENCE_LENGTH = X_verified.shape[1]
FEATURE_SIZE = X_verified.shape[2]

print("X_verified:", X_verified.shape)
print("X_test:", X_test.shape)
print("num_classes:", num_classes)
print(label_names)
# Out:
# X_verified: (11897, 48, 300)
# X_test: (1293, 48, 300)
# num_classes: 21
# ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raise', 'leg extension', 'leg raises', 'pull Up', 'push-up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep Pushdown', 'tricep dips']

# %%
# ============================================================
# 4. Scaling + augmentation helpers
# ============================================================
def scale_sequence_data(X_train, X_val):
    n_train, t, f = X_train.shape
    n_val = X_val.shape[0]

    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(
        X_train.reshape(-1, f)
    ).reshape(n_train, t, f)

    X_val_scaled = scaler.transform(
        X_val.reshape(-1, f)
    ).reshape(n_val, t, f)

    return X_train_scaled.astype(np.float32), X_val_scaled.astype(np.float32), scaler


def scale_with_existing_scaler(X, scaler):
    n, t, f = X.shape

    return scaler.transform(
        X.reshape(-1, f)
    ).reshape(n, t, f).astype(np.float32)


def augment_sequence(seq):
    aug = seq.copy()

    aug += np.random.normal(0, 0.015, size=aug.shape)
    aug *= np.random.normal(1.0, 0.025)

    shift = np.random.randint(-4, 5)
    aug = np.roll(aug, shift=shift, axis=0)

    for i in range(1, len(aug)):
        if np.random.rand() < 0.06:
            aug[i] = aug[i - 1]

    if np.random.rand() < 0.15:
        mask_len = np.random.randint(1, 6)
        start = np.random.randint(0, max(1, len(aug) - mask_len))
        replacement = aug[start - 1] if start > 0 else aug[start]
        aug[start:start + mask_len] = replacement

    feature_mask = np.random.rand(aug.shape[1]) < 0.04
    aug[:, feature_mask] = 0

    return aug.astype(np.float32)


def make_augmented_training_data(X_train, y_train, copies=2):
    X_list = [X_train]
    y_list = [y_train]

    for _ in range(copies):
        X_aug = np.array([augment_sequence(seq) for seq in X_train], dtype=np.float32)
        X_list.append(X_aug)
        y_list.append(y_train)

    return np.concatenate(X_list), np.concatenate(y_list)

# %%
# ============================================================
# 5. CNN-only model
# ============================================================
class WorkoutClassifierCNN(nn.Module):
    def __init__(self, input_size, num_classes, dropout=0.3):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv1d(input_size, 96, kernel_size=3, padding=1),
            nn.BatchNorm1d(96),
            nn.ReLU(),
            nn.Dropout(dropout * 0.6),

            nn.Conv1d(96, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(dropout * 0.7),

            nn.Conv1d(128, 192, kernel_size=3, padding=1),
            nn.BatchNorm1d(192),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Conv1d(192, 256, kernel_size=3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # Input: batch, time, features
        x = x.transpose(1, 2)

        x = self.features(x)

        avg_pool = torch.mean(x, dim=2)
        max_pool = torch.max(x, dim=2).values

        x = torch.cat([avg_pool, max_pool], dim=1)

        return self.classifier(x)


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(model)
    print(f"Total params: {total:,}")
    print(f"Trainable params: {trainable:,}")

# %%
# ============================================================
# 6. Training helpers
# ============================================================
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for batch_X, batch_y in loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(batch_y).sum().item()
        total += batch_y.size(0)

    return total_loss / len(loader), correct / total


def evaluate(model, loader, criterion, device):
    model.eval()

    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch_X, batch_y in loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)

            total_loss += loss.item()

            _, predicted = outputs.max(1)
            correct += predicted.eq(batch_y).sum().item()
            total += batch_y.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(batch_y.cpu().numpy())

    return total_loss / len(loader), correct / total, all_preds, all_labels

# %%
# ============================================================
# 7. Train with GroupKFold on verified data
# ============================================================
gkf = GroupKFold(n_splits=N_SPLITS)
groups = kept_verified_df["filepath"].values

fold_accuracies = []
fold_macro_f1 = []
fold_weighted_f1 = []

all_true = []
all_pred = []

best_val_acc = 0
best_model_state = None
best_scaler = None
best_history = None
best_fold = None

for fold, (train_idx, val_idx) in enumerate(
    gkf.split(X_verified, y_verified, groups=groups),
    start=1
):
    print(f"\n================ Fold {fold} ================")

    X_train_raw = X_verified[train_idx]
    X_val_raw = X_verified[val_idx]

    y_train = y_verified[train_idx]
    y_val = y_verified[val_idx]

    X_train, X_val, scaler = scale_sequence_data(X_train_raw, X_val_raw)

    X_train_aug, y_train_aug = make_augmented_training_data(
        X_train,
        y_train,
        copies=2
    )

    train_loader = DataLoader(
        TensorDataset(torch.FloatTensor(X_train_aug), torch.LongTensor(y_train_aug)),
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=2,
        pin_memory=True
    )

    val_loader = DataLoader(
        TensorDataset(torch.FloatTensor(X_val), torch.LongTensor(y_val)),
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    model = WorkoutClassifierCNN(
        input_size=FEATURE_SIZE,
        num_classes=num_classes,
        dropout=DROPOUT
    ).to(DEVICE)

    if fold == 1:
        count_parameters(model)

    class_weights_arr = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(y_train_aug),
        y=y_train_aug
    )

    criterion = nn.CrossEntropyLoss(
        weight=torch.FloatTensor(class_weights_arr).to(DEVICE)
    )

    optimizer = optim.Adam(
        model.parameters(),
        lr=LR,
        weight_decay=WEIGHT_DECAY
    )

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        patience=5,
        factor=0.5
    )

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": []
    }

    fold_best_acc = 0
    fold_best_state = None
    patience = 15
    patience_counter = 0

    for epoch in range(1, EPOCHS + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc, val_preds, val_labels = evaluate(model, val_loader, criterion, DEVICE)

        scheduler.step(val_loss)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        if val_acc > fold_best_acc:
            fold_best_acc = val_acc
            fold_best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch == 1 or epoch % 5 == 0:
            print(
                f"Epoch {epoch:03d}/{EPOCHS} | "
                f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
                f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
            )

        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

    model.load_state_dict(fold_best_state)
    model = model.to(DEVICE)

    val_loss, val_acc, val_preds, val_labels = evaluate(model, val_loader, criterion, DEVICE)

    macro = f1_score(val_labels, val_preds, average="macro")
    weighted = f1_score(val_labels, val_preds, average="weighted")

    fold_accuracies.append(val_acc)
    fold_macro_f1.append(macro)
    fold_weighted_f1.append(weighted)

    all_true.extend(val_labels)
    all_pred.extend(val_preds)

    print(f"\nFold {fold} Best Accuracy: {val_acc:.4f}")
    print(f"Fold {fold} Macro F1: {macro:.4f}")
    print(f"Fold {fold} Weighted F1: {weighted:.4f}")

    print(classification_report(
        val_labels,
        val_preds,
        target_names=label_names,
        zero_division=0
    ))

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        best_scaler = scaler
        best_history = history
        best_fold = fold

print("\n================ Overall CV Results ================")
print("Mean Accuracy:", np.mean(fold_accuracies))
print("Mean Macro F1:", np.mean(fold_macro_f1))
print("Mean Weighted F1:", np.mean(fold_weighted_f1))
print("Best Fold:", best_fold)
print("Best Fold Accuracy:", best_val_acc)
# Out:
# ================ Fold 1 ================
# WorkoutClassifierCNN(
#   (features): Sequential(
#     (0): Conv1d(300, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.18, inplace=False)
#     (4): Conv1d(96, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.21, inplace=False)
#     (8): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3, inplace=False)
#     (12): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (13): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )
# Total params: 537,973
# Trainable params: 537,973
# Epoch 001/80 | Train Loss: 1.3333 | Train Acc: 0.5359 | Val Loss: 0.8481 | Val Acc: 0.7298
# Epoch 005/80 | Train Loss: 0.3605 | Train Acc: 0.8782 | Val Loss: 0.6938 | Val Acc: 0.8450
# Epoch 010/80 | Train Loss: 0.2084 | Train Acc: 0.9317 | Val Loss: 0.8421 | Val Acc: 0.8454
# Epoch 015/80 | Train Loss: 0.0990 | Train Acc: 0.9690 | Val Loss: 1.3245 | Val Acc: 0.8441
# Epoch 020/80 | Train Loss: 0.0494 | Train Acc: 0.9847 | Val Loss: 1.4466 | Val Acc: 0.8538
# Epoch 025/80 | Train Loss: 0.0381 | Train Acc: 0.9881 | Val Loss: 1.2798 | Val Acc: 0.8655
# Epoch 030/80 | Train Loss: 0.0251 | Train Acc: 0.9919 | Val Loss: 1.4572 | Val Acc: 0.8592
# Epoch 035/80 | Train Loss: 0.0224 | Train Acc: 0.9930 | Val Loss: 1.3523 | Val Acc: 0.8655
# Epoch 040/80 | Train Loss: 0.0166 | Train Acc: 0.9953 | Val Loss: 1.4080 | Val Acc: 0.8676
# Epoch 045/80 | Train Loss: 0.0165 | Train Acc: 0.9953 | Val Loss: 1.5143 | Val Acc: 0.8647
# Epoch 050/80 | Train Loss: 0.0185 | Train Acc: 0.9947 | Val Loss: 1.4688 | Val Acc: 0.8609
# Early stopping at epoch 54
#
# Fold 1 Best Accuracy: 0.8697
# Fold 1 Macro F1: 0.8599
# Fold 1 Weighted F1: 0.8660
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.79      0.78      0.78       125
#         bench press       0.78      0.49      0.60       135
#   chest fly machine       0.85      0.87      0.86       140
#            deadlift       0.88      0.97      0.92        95
# decline bench press       0.80      0.94      0.87       177
#         hammer curl       0.66      0.71      0.68        92
#          hip thrust       0.95      0.75      0.84       103
# incline bench press       0.73      0.79      0.76        84
#        lat pulldown       0.76      0.90      0.82        70
#       lateral raise       0.96      0.98      0.97        93
#       leg extension       0.97      0.96      0.96       126
#          leg raises       0.99      0.98      0.98       174
#             pull Up       0.93      0.98      0.95       102
#             push-up       0.92      1.00      0.96       157
#   romanian deadlift       0.89      0.82      0.85        85
#       russian twist       0.84      1.00      0.91        83
#      shoulder press       0.86      0.80      0.83        99
#               squat       0.96      0.96      0.96       161
#           t bar row       0.78      0.97      0.87       104
#     tricep Pushdown       0.97      0.86      0.91        77
#         tricep dips       0.98      0.63      0.77        98
#
#            accuracy                           0.87      2380
#           macro avg       0.87      0.86      0.86      2380
#        weighted avg       0.87      0.87      0.87      2380
#
#
# ================ Fold 2 ================
# Epoch 001/80 | Train Loss: 1.2724 | Train Acc: 0.5693 | Val Loss: 0.8020 | Val Acc: 0.7567
# Epoch 005/80 | Train Loss: 0.3712 | Train Acc: 0.8760 | Val Loss: 0.7057 | Val Acc: 0.8017
# Epoch 010/80 | Train Loss: 0.2235 | Train Acc: 0.9290 | Val Loss: 0.7934 | Val Acc: 0.8403
# Epoch 015/80 | Train Loss: 0.1623 | Train Acc: 0.9518 | Val Loss: 0.8005 | Val Acc: 0.8529
# Epoch 020/80 | Train Loss: 0.0723 | Train Acc: 0.9784 | Val Loss: 0.9083 | Val Acc: 0.8651
# Epoch 025/80 | Train Loss: 0.0372 | Train Acc: 0.9879 | Val Loss: 1.0591 | Val Acc: 0.8664
# Epoch 030/80 | Train Loss: 0.0344 | Train Acc: 0.9914 | Val Loss: 1.0440 | Val Acc: 0.8794
# Epoch 035/80 | Train Loss: 0.0238 | Train Acc: 0.9930 | Val Loss: 1.1611 | Val Acc: 0.8723
# Epoch 040/80 | Train Loss: 0.0168 | Train Acc: 0.9951 | Val Loss: 1.1636 | Val Acc: 0.8731
# Epoch 045/80 | Train Loss: 0.0160 | Train Acc: 0.9961 | Val Loss: 1.1752 | Val Acc: 0.8756
# Early stopping at epoch 46
#
# Fold 2 Best Accuracy: 0.8836
# Fold 2 Macro F1: 0.8724
# Fold 2 Weighted F1: 0.8849
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.74      0.76      0.75       157
#         bench press       0.71      0.85      0.77        85
#   chest fly machine       0.94      0.94      0.94       108
#            deadlift       0.80      0.90      0.85        87
# decline bench press       0.96      0.89      0.93       204
#         hammer curl       0.84      0.90      0.87       152
#          hip thrust       0.95      0.91      0.93       119
# incline bench press       0.79      0.90      0.84        92
#        lat pulldown       0.92      0.84      0.88        85
#       lateral raise       0.61      1.00      0.75        43
#       leg extension       1.00      0.94      0.97       153
#          leg raises       0.98      1.00      0.99       151
#             pull Up       0.98      0.80      0.88       126
#             push-up       0.89      0.99      0.94       104
#   romanian deadlift       0.85      0.85      0.85       113
#       russian twist       0.97      0.86      0.91        98
#      shoulder press       0.78      1.00      0.88        57
#               squat       0.95      0.90      0.93       177
#           t bar row       0.96      0.88      0.92       118
#     tricep Pushdown       0.77      0.66      0.71        74
#         tricep dips       0.95      0.75      0.84        77
#
#            accuracy                           0.88      2380
#           macro avg       0.87      0.88      0.87      2380
#        weighted avg       0.89      0.88      0.88      2380
#
#
# ================ Fold 3 ================
# Epoch 001/80 | Train Loss: 1.4117 | Train Acc: 0.5132 | Val Loss: 0.7812 | Val Acc: 0.7142
# Epoch 005/80 | Train Loss: 0.3711 | Train Acc: 0.8792 | Val Loss: 0.6319 | Val Acc: 0.8277
# Epoch 010/80 | Train Loss: 0.2213 | Train Acc: 0.9288 | Val Loss: 0.7359 | Val Acc: 0.8495
# Epoch 015/80 | Train Loss: 0.1025 | Train Acc: 0.9683 | Val Loss: 0.8371 | Val Acc: 0.8579
# Epoch 020/80 | Train Loss: 0.0573 | Train Acc: 0.9817 | Val Loss: 0.8700 | Val Acc: 0.8668
# Epoch 025/80 | Train Loss: 0.0493 | Train Acc: 0.9860 | Val Loss: 0.9095 | Val Acc: 0.8752
# Epoch 030/80 | Train Loss: 0.0304 | Train Acc: 0.9907 | Val Loss: 0.9728 | Val Acc: 0.8714
# Epoch 035/80 | Train Loss: 0.0198 | Train Acc: 0.9943 | Val Loss: 0.9842 | Val Acc: 0.8739
# Epoch 040/80 | Train Loss: 0.0173 | Train Acc: 0.9950 | Val Loss: 1.0771 | Val Acc: 0.8731
# Epoch 045/80 | Train Loss: 0.0139 | Train Acc: 0.9952 | Val Loss: 1.0963 | Val Acc: 0.8693
# Epoch 050/80 | Train Loss: 0.0157 | Train Acc: 0.9949 | Val Loss: 1.0808 | Val Acc: 0.8739
# Epoch 055/80 | Train Loss: 0.0151 | Train Acc: 0.9955 | Val Loss: 1.0539 | Val Acc: 0.8731
# Early stopping at epoch 56
#
# Fold 3 Best Accuracy: 0.8802
# Fold 3 Macro F1: 0.8696
# Fold 3 Weighted F1: 0.8805
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.70      0.78      0.74       166
#         bench press       0.62      0.68      0.65       123
#   chest fly machine       0.96      0.99      0.97       153
#            deadlift       0.86      0.95      0.90        78
# decline bench press       0.85      0.83      0.84       191
#         hammer curl       0.92      0.81      0.86       235
#          hip thrust       0.89      0.97      0.93       114
# incline bench press       0.92      0.97      0.94       128
#        lat pulldown       0.94      0.76      0.84        45
#       lateral raise       0.84      0.83      0.84        59
#       leg extension       0.90      0.82      0.86       112
#          leg raises       0.97      1.00      0.98        98
#             pull Up       1.00      0.95      0.97       160
#             push-up       1.00      0.93      0.96       113
#   romanian deadlift       0.83      0.79      0.81        62
#       russian twist       0.98      0.90      0.94       108
#      shoulder press       0.80      0.97      0.88        34
#               squat       0.95      1.00      0.97       171
#           t bar row       0.76      0.93      0.84       106
#     tricep Pushdown       0.81      0.52      0.63        33
#         tricep dips       0.97      0.82      0.89        90
#
#            accuracy                           0.88      2379
#           macro avg       0.88      0.87      0.87      2379
#        weighted avg       0.89      0.88      0.88      2379
#
#
# ================ Fold 4 ================
# Epoch 001/80 | Train Loss: 1.3481 | Train Acc: 0.5443 | Val Loss: 0.8495 | Val Acc: 0.7201
# Epoch 005/80 | Train Loss: 0.3501 | Train Acc: 0.8865 | Val Loss: 0.6663 | Val Acc: 0.8121
# Epoch 010/80 | Train Loss: 0.1482 | Train Acc: 0.9509 | Val Loss: 0.7487 | Val Acc: 0.8600
# Epoch 015/80 | Train Loss: 0.1009 | Train Acc: 0.9690 | Val Loss: 0.8868 | Val Acc: 0.8609
# Epoch 020/80 | Train Loss: 0.0514 | Train Acc: 0.9840 | Val Loss: 1.0346 | Val Acc: 0.8546
# Epoch 025/80 | Train Loss: 0.0360 | Train Acc: 0.9898 | Val Loss: 1.0030 | Val Acc: 0.8642
# Epoch 030/80 | Train Loss: 0.0277 | Train Acc: 0.9929 | Val Loss: 1.0535 | Val Acc: 0.8651
# Epoch 035/80 | Train Loss: 0.0226 | Train Acc: 0.9943 | Val Loss: 1.0240 | Val Acc: 0.8726
# Epoch 040/80 | Train Loss: 0.0211 | Train Acc: 0.9935 | Val Loss: 1.0699 | Val Acc: 0.8684
# Epoch 045/80 | Train Loss: 0.0216 | Train Acc: 0.9936 | Val Loss: 1.0474 | Val Acc: 0.8705
# Epoch 050/80 | Train Loss: 0.0208 | Train Acc: 0.9943 | Val Loss: 1.1012 | Val Acc: 0.8689
# Early stopping at epoch 50
#
# Fold 4 Best Accuracy: 0.8726
# Fold 4 Macro F1: 0.8752
# Fold 4 Weighted F1: 0.8728
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.70      0.69      0.70       157
#         bench press       0.66      0.80      0.72        79
#   chest fly machine       0.97      0.93      0.95       116
#            deadlift       0.90      0.72      0.80       155
# decline bench press       0.88      0.83      0.85       198
#         hammer curl       0.78      0.90      0.84       120
#          hip thrust       0.86      0.83      0.84       101
# incline bench press       0.91      0.89      0.90        98
#        lat pulldown       0.86      0.88      0.87        72
#       lateral raise       0.96      1.00      0.98        88
#       leg extension       0.91      0.82      0.86       104
#          leg raises       0.98      0.98      0.98       113
#             pull Up       0.92      0.88      0.90       113
#             push-up       0.95      0.95      0.95       142
#   romanian deadlift       0.74      0.80      0.77        88
#       russian twist       0.94      0.90      0.92        73
#      shoulder press       0.92      0.98      0.95        82
#               squat       0.94      0.97      0.96       177
#           t bar row       0.79      0.95      0.86       148
#     tricep Pushdown       0.91      0.89      0.90        80
#         tricep dips       0.97      0.81      0.88        75
#
#            accuracy                           0.87      2379
#           macro avg       0.88      0.88      0.88      2379
#        weighted avg       0.88      0.87      0.87      2379
#
#
# ================ Fold 5 ================
# Epoch 001/80 | Train Loss: 1.3110 | Train Acc: 0.5592 | Val Loss: 0.7799 | Val Acc: 0.7381
# Epoch 005/80 | Train Loss: 0.3588 | Train Acc: 0.8778 | Val Loss: 0.6666 | Val Acc: 0.8268
# Epoch 010/80 | Train Loss: 0.1620 | Train Acc: 0.9451 | Val Loss: 0.7859 | Val Acc: 0.8604
# Epoch 015/80 | Train Loss: 0.1091 | Train Acc: 0.9662 | Val Loss: 0.8079 | Val Acc: 0.8630
# Epoch 020/80 | Train Loss: 0.0541 | Train Acc: 0.9838 | Val Loss: 0.8731 | Val Acc: 0.8785
# Epoch 025/80 | Train Loss: 0.0365 | Train Acc: 0.9894 | Val Loss: 0.9378 | Val Acc: 0.8768
# Epoch 030/80 | Train Loss: 0.0271 | Train Acc: 0.9915 | Val Loss: 0.8950 | Val Acc: 0.8873
# Epoch 035/80 | Train Loss: 0.0259 | Train Acc: 0.9923 | Val Loss: 1.0362 | Val Acc: 0.8747
# Epoch 040/80 | Train Loss: 0.0249 | Train Acc: 0.9926 | Val Loss: 1.0182 | Val Acc: 0.8815
# Epoch 045/80 | Train Loss: 0.0208 | Train Acc: 0.9936 | Val Loss: 0.9547 | Val Acc: 0.8878
# Epoch 050/80 | Train Loss: 0.0204 | Train Acc: 0.9942 | Val Loss: 0.9389 | Val Acc: 0.8831
# Epoch 055/80 | Train Loss: 0.0201 | Train Acc: 0.9938 | Val Loss: 0.9356 | Val Acc: 0.8815
# Early stopping at epoch 57
#
# Fold 5 Best Accuracy: 0.8903
# Fold 5 Macro F1: 0.8897
# Fold 5 Weighted F1: 0.8906
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.83      0.88      0.85       114
#         bench press       0.73      0.68      0.70        93
#   chest fly machine       0.88      0.96      0.92       112
#            deadlift       0.82      0.86      0.84       118
# decline bench press       0.84      0.98      0.90       157
#         hammer curl       0.82      0.92      0.86       149
#          hip thrust       0.95      0.99      0.97        93
# incline bench press       0.80      0.89      0.84        71
#        lat pulldown       0.76      0.78      0.77       102
#       lateral raise       0.98      0.85      0.91       156
#       leg extension       0.99      0.94      0.97       119
#          leg raises       0.98      0.91      0.94       111
#             pull Up       0.93      0.90      0.91       124
#             push-up       0.99      0.94      0.96       183
#   romanian deadlift       0.85      0.84      0.85       168
#       russian twist       0.99      0.97      0.98       101
#      shoulder press       0.80      0.76      0.78       102
#               squat       0.94      0.95      0.95       104
#           t bar row       0.94      0.85      0.90       110
#     tricep Pushdown       0.96      0.87      0.91        53
#         tricep dips       1.00      0.92      0.96        39
#
#            accuracy                           0.89      2379
#           macro avg       0.89      0.89      0.89      2379
#        weighted avg       0.89      0.89      0.89      2379
#
#
# ================ Overall CV Results ================
# Mean Accuracy: 0.8792977417953309
# Mean Macro F1: 0.8733626954084045
# Mean Weighted F1: 0.878959963727808
# Best Fold: 5
# Best Fold Accuracy: 0.8902900378310215

# %%
# ============================================================
# 8. Save CV results + graphs
# ============================================================
results_df = pd.DataFrame({
    "fold": list(range(1, len(fold_accuracies) + 1)),
    "accuracy": fold_accuracies,
    "macro_f1": fold_macro_f1,
    "weighted_f1": fold_weighted_f1
})

CV_RESULTS_PATH = os.path.join(OUTPUT_RESULT_DIR, "torch_cnn_cv_results.csv")
results_df.to_csv(CV_RESULTS_PATH, index=False)

display(results_df)

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_acc"], label="train_acc")
plt.plot(best_history["val_acc"], label="val_acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title(f"PyTorch CNN Accuracy - Best Fold {best_fold}")
plt.legend()

ACC_PLOT_PATH = os.path.join(OUTPUT_GRAPH_DIR, "torch_cnn_accuracy.png")
plt.savefig(ACC_PLOT_PATH, dpi=200, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(best_history["train_loss"], label="train_loss")
plt.plot(best_history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"PyTorch CNN Loss - Best Fold {best_fold}")
plt.legend()

LOSS_PLOT_PATH = os.path.join(OUTPUT_GRAPH_DIR, "torch_cnn_loss.png")
plt.savefig(LOSS_PLOT_PATH, dpi=200, bbox_inches="tight")
plt.show()
# Out:
#    fold  accuracy  macro_f1  weighted_f1
# 0     1  0.869748  0.859947     0.865981
# 1     2  0.883613  0.872376     0.884950
# 2     3  0.880202  0.869577     0.880455
# 3     4  0.872636  0.875218     0.872823
# 4     5  0.890290  0.889696     0.890591

# %%
# ============================================================
# 9. CV classification report + confusion matrix
# ============================================================
overall_report = classification_report(
    all_true,
    all_pred,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

report_df = pd.DataFrame(overall_report).transpose()

REPORT_PATH = os.path.join(OUTPUT_RESULT_DIR, "torch_cnn_cv_classification_report.csv")
report_df.to_csv(REPORT_PATH)

display(report_df)

cm = confusion_matrix(all_true, all_pred)

plt.figure(figsize=(12, 10))
plt.imshow(cm)
plt.title("PyTorch CNN CV Confusion Matrix")
plt.colorbar()
plt.xticks(range(len(label_names)), label_names, rotation=90)
plt.yticks(range(len(label_names)), label_names)
plt.tight_layout()

CM_PATH = os.path.join(OUTPUT_GRAPH_DIR, "torch_cnn_cv_confusion_matrix.png")
plt.savefig(CM_PATH, dpi=200, bbox_inches="tight")
plt.show()
# Out:
#                      precision    recall  f1-score       support
# barbell biceps curl   0.745308  0.773296  0.759044    719.000000
# bench press           0.693227  0.675728  0.684366    515.000000
# chest fly machine     0.919129  0.939587  0.929245    629.000000
# deadlift              0.852886  0.859287  0.856075    533.000000
# decline bench press   0.864921  0.891046  0.877790    927.000000
# hammer curl           0.821935  0.851604  0.836507    748.000000
# hip thrust            0.916505  0.890566  0.903349    530.000000
# incline bench press   0.837624  0.894292  0.865031    473.000000
# lat pulldown          0.831551  0.831551  0.831551    374.000000
# lateral raise         0.893570  0.917995  0.905618    439.000000
# leg extension         0.960139  0.902280  0.930311    614.000000
# leg raises            0.981337  0.975270  0.978295    647.000000
# pull Up               0.954237  0.900800  0.926749    625.000000
# push-up               0.949153  0.961373  0.955224    699.000000
# romanian deadlift     0.835294  0.825581  0.830409    516.000000
# russian twist         0.942731  0.924406  0.933479    463.000000
# shoulder press        0.838462  0.874332  0.856021    374.000000
# squat                 0.948622  0.958228  0.953401    790.000000
# t bar row             0.832817  0.918089  0.873377    586.000000
# tricep Pushdown       0.892473  0.785489  0.835570    317.000000
# tricep dips           0.973244  0.767810  0.858407    379.000000
# accuracy              0.879297  0.879297  0.879297      0.879297
# macro avg             0.880246  0.872315  0.875229  11897.000000
# weighted avg          0.881064  0.879297  0.879384  11897.000000

# %%
# ============================================================
# 10. Retrain final CNN on ALL verified data
# ============================================================
final_scaler = StandardScaler()

n, t, f = X_verified.shape

X_verified_scaled = final_scaler.fit_transform(
    X_verified.reshape(-1, f)
).reshape(n, t, f).astype(np.float32)

X_verified_aug, y_verified_aug = make_augmented_training_data(
    X_verified_scaled,
    y_verified,
    copies=2
)

train_loader = DataLoader(
    TensorDataset(torch.FloatTensor(X_verified_aug), torch.LongTensor(y_verified_aug)),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

final_model = WorkoutClassifierCNN(
    input_size=FEATURE_SIZE,
    num_classes=num_classes,
    dropout=DROPOUT
).to(DEVICE)

class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_verified_aug),
    y=y_verified_aug
)

criterion = nn.CrossEntropyLoss(
    weight=torch.FloatTensor(class_weights_arr).to(DEVICE)
)

optimizer = optim.Adam(
    final_model.parameters(),
    lr=LR,
    weight_decay=WEIGHT_DECAY
)

FINAL_EPOCHS = 40

for epoch in range(1, FINAL_EPOCHS + 1):
    train_loss, train_acc = train_one_epoch(
        final_model,
        train_loader,
        criterion,
        optimizer,
        DEVICE
    )

    if epoch == 1 or epoch % 5 == 0:
        print(f"Final Epoch {epoch:03d}/{FINAL_EPOCHS} | Loss: {train_loss:.4f} | Acc: {train_acc:.4f}")

final_model.eval()
# Out:
# Final Epoch 001/40 | Loss: 1.1829 | Acc: 0.6037
# Final Epoch 005/40 | Loss: 0.3391 | Acc: 0.8843
# Final Epoch 010/40 | Loss: 0.2074 | Acc: 0.9335
# Final Epoch 015/40 | Loss: 0.1487 | Acc: 0.9548
# Final Epoch 020/40 | Loss: 0.1201 | Acc: 0.9642
# Final Epoch 025/40 | Loss: 0.1035 | Acc: 0.9704
# Final Epoch 030/40 | Loss: 0.0921 | Acc: 0.9761
# Final Epoch 035/40 | Loss: 0.0833 | Acc: 0.9765
# Final Epoch 040/40 | Loss: 0.0775 | Acc: 0.9792
# WorkoutClassifierCNN(
#   (features): Sequential(
#     (0): Conv1d(300, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.18, inplace=False)
#     (4): Conv1d(96, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.21, inplace=False)
#     (8): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3, inplace=False)
#     (12): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (13): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=128, out_features=21, bias=True)
#   )
# )

# %%
# ============================================================
# 11. Evaluate final model on official test split
# ============================================================
X_test_scaled = scale_with_existing_scaler(X_test, final_scaler)

test_loader = DataLoader(
    TensorDataset(torch.FloatTensor(X_test_scaled), torch.LongTensor(y_test)),
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loss, test_acc, test_preds, test_labels = evaluate(
    final_model,
    test_loader,
    criterion,
    DEVICE
)

test_macro = f1_score(test_labels, test_preds, average="macro")
test_weighted = f1_score(test_labels, test_preds, average="weighted")

print("Official Test Accuracy:", test_acc)
print("Official Test Macro F1:", test_macro)
print("Official Test Weighted F1:", test_weighted)

print(classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0
))
# Out:
# Official Test Accuracy: 0.5452436194895591
# Official Test Macro F1: 0.5235660696188065
# Official Test Weighted F1: 0.5417767074640079
#                      precision    recall  f1-score   support
#
# barbell biceps curl       0.27      0.71      0.40        49
#         bench press       0.19      0.64      0.29        36
#   chest fly machine       0.77      0.72      0.74        89
#            deadlift       0.70      0.72      0.71       156
# decline bench press       0.40      0.51      0.45        83
#         hammer curl       0.03      0.02      0.02        49
#          hip thrust       0.62      0.51      0.56        70
# incline bench press       0.00      0.00      0.00        77
#        lat pulldown       0.54      0.38      0.45        34
#       lateral raise       0.62      0.50      0.55        26
#       leg extension       0.71      0.97      0.82        36
#          leg raises       0.89      0.70      0.78        70
#             pull Up       0.80      0.63      0.70        62
#             push-up       1.00      0.44      0.61        82
#   romanian deadlift       0.32      0.24      0.28        50
#       russian twist       0.64      0.96      0.77        28
#      shoulder press       0.90      0.55      0.68        69
#               squat       0.33      0.16      0.22        55
#           t bar row       0.53      0.51      0.52        72
#     tricep Pushdown       0.44      1.00      0.61        27
#         tricep dips       0.86      0.77      0.81        73
#
#            accuracy                           0.55      1293
#           macro avg       0.55      0.56      0.52      1293
#        weighted avg       0.59      0.55      0.54      1293

# %%
# ============================================================
# 12. Save official test report + confusion matrix
# ============================================================
test_report = classification_report(
    test_labels,
    test_preds,
    target_names=label_names,
    zero_division=0,
    output_dict=True
)

test_report_df = pd.DataFrame(test_report).transpose()

TEST_REPORT_PATH = os.path.join(OUTPUT_RESULT_DIR, "torch_cnn_official_test_report.csv")
test_report_df.to_csv(TEST_REPORT_PATH)

display(test_report_df)

test_cm = confusion_matrix(test_labels, test_preds)

plt.figure(figsize=(12, 10))
plt.imshow(test_cm)
plt.title("PyTorch CNN Official Test Confusion Matrix")
plt.colorbar()
plt.xticks(range(len(label_names)), label_names, rotation=90)
plt.yticks(range(len(label_names)), label_names)
plt.tight_layout()

TEST_CM_PATH = os.path.join(OUTPUT_GRAPH_DIR, "torch_cnn_official_test_confusion_matrix.png")
plt.savefig(TEST_CM_PATH, dpi=200, bbox_inches="tight")
plt.show()
# Out:
#                      precision    recall  f1-score      support
# barbell biceps curl   0.273438  0.714286  0.395480    49.000000
# bench press           0.186992  0.638889  0.289308    36.000000
# chest fly machine     0.771084  0.719101  0.744186    89.000000
# deadlift              0.697531  0.724359  0.710692   156.000000
# decline bench press   0.403846  0.506024  0.449198    83.000000
# hammer curl           0.028571  0.020408  0.023810    49.000000
# hip thrust            0.620690  0.514286  0.562500    70.000000
# incline bench press   0.000000  0.000000  0.000000    77.000000
# lat pulldown          0.541667  0.382353  0.448276    34.000000
# lateral raise         0.619048  0.500000  0.553191    26.000000
# leg extension         0.714286  0.972222  0.823529    36.000000
# leg raises            0.890909  0.700000  0.784000    70.000000
# pull Up               0.795918  0.629032  0.702703    62.000000
# push-up               1.000000  0.439024  0.610169    82.000000
# romanian deadlift     0.324324  0.240000  0.275862    50.000000
# russian twist         0.642857  0.964286  0.771429    28.000000
# shoulder press        0.904762  0.550725  0.684685    69.000000
# squat                 0.333333  0.163636  0.219512    55.000000
# t bar row             0.528571  0.513889  0.521127    72.000000
# tricep Pushdown       0.442623  1.000000  0.613636    27.000000
# tricep dips           0.861538  0.767123  0.811594    73.000000
# accuracy              0.545244  0.545244  0.545244     0.545244
# macro avg             0.551523  0.555221  0.523566  1293.000000
# weighted avg          0.586043  0.545244  0.541777  1293.000000

# %%
# ============================================================
# 13. Save checkpoint + scaler + labels
# ============================================================
CHECKPOINT_PATH = os.path.join(
    OUTPUT_MODEL_DIR,
    "best_workout_cnn_model.pth"
)

checkpoint = {
    "model_state_dict": final_model.cpu().state_dict(),
    "hyperparams": {
        "input_size": FEATURE_SIZE,
        "num_classes": num_classes,
        "dropout": DROPOUT,
        "sequence_length": SEQUENCE_LENGTH
    },
    "label_names": label_names,
    "test_accuracy": test_acc,
    "test_macro_f1": test_macro,
    "test_weighted_f1": test_weighted
}

torch.save(checkpoint, CHECKPOINT_PATH)

SCALER_JSON_PATH = os.path.join(OUTPUT_MODEL_DIR, "mediapipe_scaler.json")

with open(SCALER_JSON_PATH, "w") as f:
    json.dump({
        "mean": final_scaler.mean_.tolist(),
        "scale": final_scaler.scale_.tolist()
    }, f)

LABEL_PATH = os.path.join(OUTPUT_MODEL_DIR, "label_names.json")

with open(LABEL_PATH, "w") as f:
    json.dump(label_names, f)

print("Saved checkpoint:", CHECKPOINT_PATH)
print("Saved scaler:", SCALER_JSON_PATH)
print("Saved labels:", LABEL_PATH)
# Out:
# Saved checkpoint: /content/drive/MyDrive/UChicago/Masters/Spring/Computer Vision/Computer Vision Final Project/mediapipe_pose_exercise_new_dataset/torch_cnn_coreml/best_workout_cnn_model_new_dataset.pth
# Saved scaler: /content/drive/MyDrive/UChicago/Masters/Spring/Computer Vision/Computer Vision Final Project/mediapipe_pose_exercise_new_dataset/torch_cnn_coreml/mediapipe_scaler.json
# Saved labels: /content/drive/MyDrive/UChicago/Masters/Spring/Computer Vision/Computer Vision Final Project/mediapipe_pose_exercise_new_dataset/torch_cnn_coreml/label_names.json

# %%
# ============================================================
# 14. Convert final CNN model to CoreML
# ============================================================
export_model = WorkoutClassifierCNN(
    input_size=FEATURE_SIZE,
    num_classes=num_classes,
    dropout=DROPOUT
)

export_model.load_state_dict(checkpoint["model_state_dict"])
export_model.eval()

example_input = torch.rand(1, SEQUENCE_LENGTH, FEATURE_SIZE)

with torch.no_grad():
    example_output = export_model(example_input)

print("Example input:", example_input.shape)
print("Example output:", example_output.shape)

traced_model = torch.jit.trace(export_model, example_input)

coreml_model = ct.convert(
    traced_model,
    inputs=[
        ct.TensorType(
            name="input",
            shape=example_input.shape
        )
    ],
    outputs=[
        ct.TensorType(name="logits")
    ],
    convert_to="mlprogram",
    minimum_deployment_target=ct.target.iOS15
)

COREML_PATH = os.path.join(OUTPUT_MODEL_DIR, "WorkoutClassifierCNN.mlpackage")
coreml_model.save(COREML_PATH)

print("Saved CoreML model:", COREML_PATH)
# Out:
# Example input: torch.Size([1, 48, 300])
# Example output: torch.Size([1, 21])
# Converting PyTorch Frontend ==> MIL Ops:  98%|█████████▊| 63/64 [00:00<00:00, 3871.27 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 593.44 passes/s]
# Running MIL default pipeline: 100%|██████████| 95/95 [00:00<00:00, 550.45 passes/s]
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 1076.57 passes/s]
# Saved CoreML model: /content/drive/MyDrive/UChicago/Masters/Spring/Computer Vision/Computer Vision Final Project/mediapipe_pose_exercise_new_dataset/torch_cnn_coreml/WorkoutClassifierCNN.mlpackage
